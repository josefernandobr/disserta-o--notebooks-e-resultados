# %% [markdown]
# Obs: falta gerar os notebooks para SimpleRNN, SimpleRNN e bi-SimpleRNN

# %%
from google.colab import drive #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
drive.mount('/content/gdrive')
from IPython.display import Image
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # validação cruzada- método 2- split cross validation

# %%
Image("gdrive/My Drive/dissertação/split.png") #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ####pré-processamento dos dados

# %%
# df_av_new = pd.read_csv("gdrive/My Drive/dadoscorrigidos/df_av_new.csv",sep=",") #######!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! 29-08
# df_av_new=pd.read_csv("gdrive/My Drive/dadoscorrigidos/df_av_new.csv",sep=",")
# df_av_new=pd.read_csv("gdrive/My Drive/dadoscorrigidos/df_av_new.csv",sep=",")
df_av_new=pd.read_csv("gdrive/My Drive/dadoscorrigidos/df_av_new.csv",sep=",")

# Temp_av ############################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!29-08


#####################################Tijuca#################################

# def change_Temp_av(value):
#     if value>=24.425479+3*5.604246:
#         value=None
#     return value

# # NOx_av
# def change_NOx_av(value):
#     if value>=57.234630+3*35.907004:
#         value=None
#     return value
        
# # CO_av
# def change_CO_av(value):
#     if value>=00.401154+3*0.253000:
#         value=None
#     return value
        
# # Chuva_av
# def change_Chuva_av(value):
#     if value>=0.150894+3*3.708688:
#         value=None
#     return value

# # Pres_av
# def change_Pres_av(value):
#     if value>=1015.099332+3*5.384967:
#         value=None
#     return value
        
# # Vel_Vento_av
# def change_Vel_Vento_av(value):
#     if value>=0.740544+3*1.126588:
#         value=None
#     return value
        
# # SO2_av
# def change_SO2_av(value):
#     if value>=3.910194+3*5.948402:
#         value=None
#     return value

# # PM10_av
# def change_PM10_av(value):
#     if value>=32.822450+3*18.905713:
#         value=None
#     return value
        
# # O3_av
# def change_O3_av(value):
#     if value>=28.441701+3*24.958795:
#         value=None
#     return value
        
# # UR_av
# def change_UR_av(value):
#     if value>=65.761545+3*19.409196:
#         value=None
#     return value

# # NO_av 
# def change_NO_av(value):
#     if value>=33.860255+3*25.161391:
#         value=None
#     return value
        
# # NO2_av
# def change_NO2_av(value):
#     if value>=40.879302+3*23.167150:
#         value=None
#     return value

# df_av_new['Temp_av']=df_av_new['Temp_av'].apply(change_Temp_av)
# df_av_new['NOx_av']=df_av_new['NOx_av'].apply(change_NOx_av)
# df_av_new['CO_av']=df_av_new['CO_av'].apply(change_CO_av)
# df_av_new['Chuva_av']=df_av_new['Chuva_av'].apply(change_Chuva_av)
# df_av_new['Pres_av']=df_av_new['Pres_av'].apply(change_Pres_av)
# df_av_new['Vel_Vento_av']=df_av_new['Vel_Vento_av'].apply(change_Vel_Vento_av)
# df_av_new['SO2_av']=df_av_new['SO2_av'].apply(change_SO2_av)
# df_av_new['PM10_av']=df_av_new['PM10_av'].apply(change_PM10_av)
# df_av_new['O3_av']=df_av_new['O3_av'].apply(change_O3_av)
# df_av_new['UR_av']=df_av_new['UR_av'].apply(change_UR_av)
# df_av_new['NO_av']=df_av_new['NO_av'].apply(change_NO_av)
# df_av_new['NO2_av']=df_av_new['NO2_av'].apply(change_NO2_av)

# df_av_new.interpolate(method='linear', inplace=True)

################################São Cristóvão ###########################################

# Temp_av #############################################29-08
# def change_Temp_av(value):
#     if value>=26.458870+3*4.815135:
#         value=None
#     return value

# # NOx_av
# def change_NOx_av(value):
#     if value>=57.234630+3*35.907004:
#         value=None
#     return value
        
# # CO_av
# def change_CO_av(value):
#     if value>=0.246643+3*0.323099:
#         value=None
#     return value
        
# # Chuva_av
# def change_Chuva_av(value):
#     if value>=0.104656+3*0.967269:
#         value=None
#     return value

# # Pres_av
# def change_Pres_av(value):
#     if value>=1014.915945+3*4.812528:
#         value=None
#     return value
        
# # Vel_Vento_av
# def change_Vel_Vento_av(value):
#     if value>=0.891442+3*0.583776:
#         value=None
#     return value
        
# # SO2_av
# def change_SO2_av(value):
#     if value>=7.701210+3*9.624276:
#         value=None
#     return value

# # PM10_av
# def change_PM10_av(value):
#     if value>=33.8148393*21.664754:
#         value=None
#     return value
        
# # O3_av
# def change_O3_av(value):
#     if value>=24.170666+3*26.649651:
#         value=None
#     return value
        
# # UR_av
# def change_UR_av(value):
#     if value>=71.781421+3*17.299195:
#         value=None
#     return value

# # NO_av 
# def change_NO_av(value):
#     if value>=33.860255+3*25.161391:
#         value=None
#     return value
        
# # NO2_av
# def change_NO2_av(value):
#     if value>=40.879302+3*23.167150:
#         value=None
#     return value

# df_av_new['Temp_av']=df_av_new['Temp_av'].apply(change_Temp_av)
# df_av_new['NOx_av']=df_av_new['NOx_av'].apply(change_NOx_av)
# df_av_new['CO_av']=df_av_new['CO_av'].apply(change_CO_av)
# df_av_new['Chuva_av']=df_av_new['Chuva_av'].apply(change_Chuva_av)
# df_av_new['Pres_av']=df_av_new['Pres_av'].apply(change_Pres_av)
# df_av_new['Vel_Vento_av']=df_av_new['Vel_Vento_av'].apply(change_Vel_Vento_av)
# df_av_new['SO2_av']=df_av_new['SO2_av'].apply(change_SO2_av)
# df_av_new['PM10_av']=df_av_new['PM10_av'].apply(change_PM10_av)
# df_av_new['O3_av']=df_av_new['O3_av'].apply(change_O3_av)
# df_av_new['UR_av']=df_av_new['UR_av'].apply(change_UR_av)
# df_av_new['NO_av']=df_av_new['NO_av'].apply(change_NO_av)
# df_av_new['NO2_av']=df_av_new['NO2_av'].apply(change_NO2_av)

# df_av_new.interpolate(method='linear', inplace=True)

############################Copacabana ##############################################

# Temp_av
def change_Temp_av(value):
    if value>=25.172788+3*4.225387:
        value=None
    return value

# NOx_av
def change_NOx_av(value):
    if value>=59.367107+3*36.146031:
        value=None
    return value
        
# CO_av
def change_CO_av(value):
    if value>=0.155905+3*0.211192:
        value=None
    return value
        
# Chuva_av
def change_Chuva_av(value):
    if value>=0.128735+3*1.101333:
        value=None
    return value

# Pres_av
def change_Pres_av(value):
    if value>=1015.258799+3*4.821615:
        value=None
    return value
        
# Vel_Vento_av
def change_Vel_Vento_av(value):
    if value>=0.701683+3*0.345451:
        value=None
    return value
        
# SO2_av
def change_SO2_av(value):
    if value>=3.469947+3*4.991061:
        value=None
    return value

# PM10_av
def change_PM10_av(value):
    if value>=54.811765+3*22.284436:
        value=None
    return value
        
# O3_av
def change_O3_av(value):
    if value>=20.051822+3*16.814262:
        value=None
    return value
        
# UR_av
def change_UR_av(value):
    if value>=72.174597+3*14.978142:
        value=None
    return value

# NO_av 
def change_NO_av(value):
    if value>=36.687934+3*25.021793:
        value=None
    return value
        
# NO2_av
def change_NO2_av(value):
    if value>=42.098616+3*23.497406:
        value=None
    return value

df_av_new['Temp_av']=df_av_new['Temp_av'].apply(change_Temp_av)
df_av_new['NOx_av']=df_av_new['NOx_av'].apply(change_NOx_av)
df_av_new['CO_av']=df_av_new['CO_av'].apply(change_CO_av)
df_av_new['Chuva_av']=df_av_new['Chuva_av'].apply(change_Chuva_av)
df_av_new['Pres_av']=df_av_new['Pres_av'].apply(change_Pres_av)
df_av_new['Vel_Vento_av']=df_av_new['Vel_Vento_av'].apply(change_Vel_Vento_av)
df_av_new['SO2_av']=df_av_new['SO2_av'].apply(change_SO2_av)
df_av_new['PM10_av']=df_av_new['PM10_av'].apply(change_PM10_av)
df_av_new['O3_av']=df_av_new['O3_av'].apply(change_O3_av)
df_av_new['UR_av']=df_av_new['UR_av'].apply(change_UR_av)
df_av_new['NO_av']=df_av_new['NO_av'].apply(change_NO_av)
df_av_new['NO2_av']=df_av_new['NO2_av'].apply(change_NO2_av)

df_av_new.interpolate(method='linear', inplace=True)

df_av_new.reset_index(inplace=True) ######!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!29-8

df_av_new['data_resolved']=df_av_new['Data'].apply(lambda x: str(x)[:10])

df_av_new = df_av_new[['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
       'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av','data_resolved']]

df_av_new = df_av_new.groupby(['data_resolved'], sort=False)['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
       'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av'].max()

names = df_av_new.columns

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() 
data_scaled = scaler.fit_transform(df_av_new)

df_av_new_scaled = pd.DataFrame(data_scaled, columns=names)

df_av_new_scaled.index=df_av_new.index

############################ Centro ##############################################

# # Temp_av
# def change_Temp_av(value):
#     if value>=25.172788+3*4.225387:
#         value=None
#     return value

# # NOx_av
# def change_NOx_av(value):
#     if value>=59.367107+3*36.146031:
#         value=None
#     return value
        
# # CO_av
# def change_CO_av(value):
#     if value>=0.155905+3*0.211192:
#         value=None
#     return value
        
# # Chuva_av
# def change_Chuva_av(value):
#     if value>=0.128735+3*1.101333:
#         value=None
#     return value

# # Pres_av
# def change_Pres_av(value):
#     if value>=1015.258799+3*4.821615:
#         value=None
#     return value
        
# # Vel_Vento_av
# def change_Vel_Vento_av(value):
#     if value>=0.701683+3*0.345451:
#         value=None
#     return value
        
# # SO2_av
# def change_SO2_av(value):
#     if value>=3.469947+3*4.991061:
#         value=None
#     return value

# # PM10_av
# def change_PM10_av(value):
#     if value>=54.811765+3*22.284436:
#         value=None
#     return value
        
# # O3_av
# def change_O3_av(value):
#     if value>=20.051822+3*16.814262:
#         value=None
#     return value
        
# # UR_av
# def change_UR_av(value):
#     if value>=72.174597+3*14.978142:
#         value=None
#     return value

# # NO_av 
# def change_NO_av(value):
#     if value>=36.687934+3*25.021793:
#         value=None
#     return value
        
# # NO2_av
# def change_NO2_av(value):
#     if value>=42.098616+3*23.497406:
#         value=None
#     return value

# df_av_new['Temp_av']=df_av_new['Temp_av'].apply(change_Temp_av)
# df_av_new['NOx_av']=df_av_new['NOx_av'].apply(change_NOx_av)
# df_av_new['CO_av']=df_av_new['CO_av'].apply(change_CO_av)
# df_av_new['Chuva_av']=df_av_new['Chuva_av'].apply(change_Chuva_av)
# df_av_new['Pres_av']=df_av_new['Pres_av'].apply(change_Pres_av)
# df_av_new['Vel_Vento_av']=df_av_new['Vel_Vento_av'].apply(change_Vel_Vento_av)
# df_av_new['SO2_av']=df_av_new['SO2_av'].apply(change_SO2_av)
# df_av_new['PM10_av']=df_av_new['PM10_av'].apply(change_PM10_av)
# df_av_new['O3_av']=df_av_new['O3_av'].apply(change_O3_av)
# df_av_new['UR_av']=df_av_new['UR_av'].apply(change_UR_av)
# df_av_new['NO_av']=df_av_new['NO_av'].apply(change_NO_av)
# df_av_new['NO2_av']=df_av_new['NO2_av'].apply(change_NO2_av)

# df_av_new.interpolate(method='linear', inplace=True)

# df_av_new.reset_index(inplace=True) ######!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!29-8

# df_av_new['data_resolved']=df_av_new['Data'].apply(lambda x: str(x)[:10])

# df_av_new = df_av_new[['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
#        'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av','data_resolved']]

# df_av_new = df_av_new.groupby(['data_resolved'], sort=False)['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
#        'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av'].max()

# names = df_av_new.columns

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# data_scaled = scaler.fit_transform(df_av_new)

# df_av_new_scaled = pd.DataFrame(data_scaled, columns=names)

# df_av_new_scaled.index=df_av_new.index



################### Tijuca ###############

# df_av_new.reset_index(inplace=True) ######!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!29-8

# df_av_new['data_resolved']=df_av_new['Data'].apply(lambda x: str(x)[:10])

# df_av_new = df_av_new[['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
#        'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av','data_resolved']]

# df_av_new = df_av_new.groupby(['data_resolved'], sort=False)['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
#        'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av'].max()

# names = df_av_new.columns

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# data_scaled = scaler.fit_transform(df_av_new)

# df_av_new_scaled = pd.DataFrame(data_scaled, columns=names)

# df_av_new_scaled.index=df_av_new.index

################ São Cristóvão ################

# df_av_new.reset_index(inplace=True) #######################29-08

# df_av_new['data_resolved']=df_av_new['Data'].apply(lambda x: str(x)[:10])

# df_av_new = df_av_new[['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
#        'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av','data_resolved']]

# df_av_new = df_av_new.groupby(['data_resolved'], sort=False)['Temp_av', 'NOx_av', 'CO_av', 'Chuva_av', 'Pres_av',
#        'Vel_Vento_av', 'SO2_av', 'PM10_av', 'O3_av', 'UR_av','NO_av','NO2_av'].max()

# names = df_av_new.columns

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# data_scaled = scaler.fit_transform(df_av_new)

# df_av_new_scaled = pd.DataFrame(data_scaled, columns=names)

# df_av_new_scaled.index=df_av_new.index

import time
import pandas as pd
import seaborn as sns
import missingno as msno
import warnings
from matplotlib import pyplot as plt
import datetime
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',100)

from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score #colocar citação

from math import sqrt
from numpy import concatenate
from matplotlib import pyplot

from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN, SimpleRNN,SimpleRNN
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed

values = df_av_new_scaled.values
values = values.astype('float32')

# convert series to supervised learning
def series_to_supervised(data, n_in=10, n_out=10, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# specify the number of lag hours
n_days = 7 #input
n_features = 12 #10 colunas !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! 29-08

#reframed = series_to_supervised(df_av_new_scaled, n_days, 1) # quebrar aqui

# %% [markdown]
# #### treinamento do modelo para primeiro 1/5 da divisão

# %%
reframed = series_to_supervised(df_av_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1056]

# split into train and test sets
values = reframed.values
n_train_days = 528

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 17/17 - 2s - loss: 0.2511 - val_loss: 0.1672 - 2s/epoch - 113ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.0774 - val_loss: 0.0866 - 86ms/epoch - 5ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0593 - val_loss: 0.0895 - 129ms/epoch - 8ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0521 - val_loss: 0.0792 - 126ms/epoch - 7ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0499 - val_loss: 0.0745 - 94ms/epoch - 6ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0476 - val_loss: 0.0705 - 96ms/epoch - 6ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0459 - val_loss: 0.0674 - 97ms/epoch - 6ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0444 - val_loss: 0.0645 - 90ms/epoch - 5ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0431 - val_loss: 0.0620 - 130ms/epoch - 8ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0419 - val_loss: 0.0599 - 128ms/epoch - 8ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0410 - val_loss: 0.0579 - 89ms/epoch - 5ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av']))
print('Test Temp_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av']))
print('Test NOx_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_av'], df_test_y['CO_av']))
print('Test CO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av']))
print('Test Chuva_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av']))
print('Test Pres_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av']))
print('Test Vel_Vento_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av']))
print('Test SO2_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av']))
print('Test PM10_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_av'], df_test_y['O3_av']))
print('Test O3_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_av'], df_test_y['UR_av']))
print('Test UR_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_av'], df_test_y['NO_av']))
print('Test NO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av']))
print('Test NO2_av RMSE: %.3f' % rmse)
# Out:
# Test Temp_av RMSE: 3.787
# Test NOx_av RMSE: 28.702
# Test CO_av RMSE: 0.197
# Test Chuva_av RMSE: 1.011
# Test Pres_av RMSE: 4.128
# Test Vel_Vento_av RMSE: 0.253
# Test SO2_av RMSE: 5.591
# Test PM10_av RMSE: 20.025
# Test O3_av RMSE: 13.922
# Test UR_av RMSE: 6.516
# Test NO_av RMSE: 17.918
# Test NO2_av RMSE: 20.139

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av MAE: %.3f' % mae)
# Out:
# Test Temp_av MAE: 3.032
# Test NOx_av MAE: 22.816
# Test CO_av MAE: 0.162
# Test Chuva_av MAE: 0.648
# Test Pres_av MAE: 3.304
# Test Vel_Vento_av MAE: 0.210
# Test SO2_av MAE: 4.684
# Test PM10_av MAE: 15.931
# Test O3_av MAE: 11.309
# Test UR_av MAE: 5.074
# Test NO_av MAE: 14.056
# Test NO2_av MAE: 15.847

# %%
r2=r2_score(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av R2: %.3f' % r2)
# Out:
# Test Temp_av R2: -0.585
# Test NOx_av R2: -0.047
# Test CO_av R2: -3.653
# Test Chuva_av R2: -5.473
# Test Pres_av R2: -0.758
# Test Vel_Vento_av R2: -4.779
# Test SO2_av R2: -4.904
# Test PM10_av R2: -0.707
# Test O3_av R2: -3.113
# Test UR_av R2: -1.257
# Test NO_av R2: -0.323
# Test NO2_av R2: -0.409

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 2/5 da divisão

# %%
reframed = series_to_supervised(df_av_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1584]

# split into train and test sets
values = reframed.values
n_train_days = 1056

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 33/33 - 2s - loss: 0.2779 - val_loss: 0.0745 - 2s/epoch - 58ms/step
# Epoch 2/150
# 33/33 - 0s - loss: 0.0751 - val_loss: 0.0637 - 205ms/epoch - 6ms/step
# Epoch 3/150
# 33/33 - 0s - loss: 0.0700 - val_loss: 0.0586 - 182ms/epoch - 6ms/step
# Epoch 4/150
# 33/33 - 0s - loss: 0.0641 - val_loss: 0.0554 - 146ms/epoch - 4ms/step
# Epoch 5/150
# 33/33 - 0s - loss: 0.0589 - val_loss: 0.0525 - 130ms/epoch - 4ms/step
# Epoch 6/150
# 33/33 - 0s - loss: 0.0547 - val_loss: 0.0502 - 136ms/epoch - 4ms/step
# Epoch 7/150
# 33/33 - 0s - loss: 0.0515 - val_loss: 0.0484 - 135ms/epoch - 4ms/step
# Epoch 8/150
# 33/33 - 0s - loss: 0.0492 - val_loss: 0.0469 - 131ms/epoch - 4ms/step
# Epoch 9/150
# 33/33 - 0s - loss: 0.0475 - val_loss: 0.0457 - 128ms/epoch - 4ms/step
# Epoch 10/150
# 33/33 - 0s - loss: 0.0462 - val_loss: 0.0446 - 133ms/epoch - 4ms/step
# Epoch 11/150
# 33/33 - 0s - loss: 0.0453 - val_loss: 0.0437 - 167ms/epoch - 5ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av']))
print('Test Temp_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av']))
print('Test NOx_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_av'], df_test_y['CO_av']))
print('Test CO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av']))
print('Test Chuva_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av']))
print('Test Pres_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av']))
print('Test Vel_Vento_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av']))
print('Test SO2_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av']))
print('Test PM10_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_av'], df_test_y['O3_av']))
print('Test O3_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_av'], df_test_y['UR_av']))
print('Test UR_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_av'], df_test_y['NO_av']))
print('Test NO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av']))
print('Test NO2_av RMSE: %.3f' % rmse)
# Out:
# Test Temp_av RMSE: 3.118
# Test NOx_av RMSE: 28.852
# Test CO_av RMSE: 0.208
# Test Chuva_av RMSE: 0.854
# Test Pres_av RMSE: 2.890
# Test Vel_Vento_av RMSE: 0.260
# Test SO2_av RMSE: 4.390
# Test PM10_av RMSE: 17.924
# Test O3_av RMSE: 12.191
# Test UR_av RMSE: 7.358
# Test NO_av RMSE: 16.111
# Test NO2_av RMSE: 15.708

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av MAE: %.3f' % mae)
# Out:
# Test Temp_av MAE: 2.374
# Test NOx_av MAE: 23.031
# Test CO_av MAE: 0.176
# Test Chuva_av MAE: 0.582
# Test Pres_av MAE: 2.221
# Test Vel_Vento_av MAE: 0.212
# Test SO2_av MAE: 3.503
# Test PM10_av MAE: 14.123
# Test O3_av MAE: 9.790
# Test UR_av MAE: 5.710
# Test NO_av MAE: 12.609
# Test NO2_av MAE: 12.490

# %%
r2=r2_score(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av R2: %.3f' % r2)
# Out:
# Test Temp_av R2: 0.298
# Test NOx_av R2: 0.165
# Test CO_av R2: -3.958
# Test Chuva_av R2: -3.676
# Test Pres_av R2: 0.509
# Test Vel_Vento_av R2: -2.795
# Test SO2_av R2: -1.629
# Test PM10_av R2: -0.647
# Test O3_av R2: -0.946
# Test UR_av R2: -1.138
# Test NO_av R2: 0.550
# Test NO2_av R2: 0.524

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 3/5 da divisão

# %%
reframed = series_to_supervised(df_av_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2112]

# split into train and test sets
values = reframed.values
n_train_days = 1584

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 50/50 - 2s - loss: 0.1485 - val_loss: 0.0592 - 2s/epoch - 43ms/step
# Epoch 2/150
# 50/50 - 0s - loss: 0.0595 - val_loss: 0.0536 - 186ms/epoch - 4ms/step
# Epoch 3/150
# 50/50 - 0s - loss: 0.0529 - val_loss: 0.0512 - 216ms/epoch - 4ms/step
# Epoch 4/150
# 50/50 - 0s - loss: 0.0489 - val_loss: 0.0488 - 194ms/epoch - 4ms/step
# Epoch 5/150
# 50/50 - 0s - loss: 0.0458 - val_loss: 0.0472 - 182ms/epoch - 4ms/step
# Epoch 6/150
# 50/50 - 0s - loss: 0.0438 - val_loss: 0.0461 - 219ms/epoch - 4ms/step
# Epoch 7/150
# 50/50 - 0s - loss: 0.0425 - val_loss: 0.0452 - 220ms/epoch - 4ms/step
# Epoch 8/150
# 50/50 - 0s - loss: 0.0414 - val_loss: 0.0443 - 207ms/epoch - 4ms/step
# Epoch 9/150
# 50/50 - 0s - loss: 0.0405 - val_loss: 0.0435 - 221ms/epoch - 4ms/step
# Epoch 10/150
# 50/50 - 0s - loss: 0.0396 - val_loss: 0.0428 - 212ms/epoch - 4ms/step
# Epoch 11/150
# 50/50 - 0s - loss: 0.0389 - val_loss: 0.0421 - 217ms/epoch - 4ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av']))
print('Test Temp_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av']))
print('Test NOx_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_av'], df_test_y['CO_av']))
print('Test CO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av']))
print('Test Chuva_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av']))
print('Test Pres_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av']))
print('Test Vel_Vento_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av']))
print('Test SO2_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av']))
print('Test PM10_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_av'], df_test_y['O3_av']))
print('Test O3_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_av'], df_test_y['UR_av']))
print('Test UR_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_av'], df_test_y['NO_av']))
print('Test NO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av']))
print('Test NO2_av RMSE: %.3f' % rmse)
# Out:
# Test Temp_av RMSE: 3.152
# Test NOx_av RMSE: 29.031
# Test CO_av RMSE: 0.191
# Test Chuva_av RMSE: 0.926
# Test Pres_av RMSE: 2.614
# Test Vel_Vento_av RMSE: 0.296
# Test SO2_av RMSE: 4.553
# Test PM10_av RMSE: 18.802
# Test O3_av RMSE: 11.579
# Test UR_av RMSE: 7.416
# Test NO_av RMSE: 23.836
# Test NO2_av RMSE: 17.595

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av MAE: %.3f' % mae)
# Out:
# Test Temp_av MAE: 2.462
# Test NOx_av MAE: 22.738
# Test CO_av MAE: 0.148
# Test Chuva_av MAE: 0.573
# Test Pres_av MAE: 2.022
# Test Vel_Vento_av MAE: 0.220
# Test SO2_av MAE: 3.796
# Test PM10_av MAE: 15.179
# Test O3_av MAE: 9.324
# Test UR_av MAE: 5.947
# Test NO_av MAE: 18.621
# Test NO2_av MAE: 13.797

# %%
r2=r2_score(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av R2: %.3f' % r2)
# Out:
# Test Temp_av R2: -0.028
# Test NOx_av R2: -0.467
# Test CO_av R2: -4.154
# Test Chuva_av R2: -4.155
# Test Pres_av R2: 0.460
# Test Vel_Vento_av R2: -6.143
# Test SO2_av R2: -2.754
# Test PM10_av R2: -0.871
# Test O3_av R2: -1.324
# Test UR_av R2: -0.768
# Test NO_av R2: -0.755
# Test NO2_av R2: 0.117

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 4/5 da divisão

# %%
reframed = series_to_supervised(df_av_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2640]

# split into train and test sets
values = reframed.values
n_train_days = 2112

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 66/66 - 2s - loss: 0.1123 - val_loss: 0.0765 - 2s/epoch - 30ms/step
# Epoch 2/150
# 66/66 - 0s - loss: 0.0627 - val_loss: 0.0646 - 251ms/epoch - 4ms/step
# Epoch 3/150
# 66/66 - 0s - loss: 0.0541 - val_loss: 0.0572 - 243ms/epoch - 4ms/step
# Epoch 4/150
# 66/66 - 0s - loss: 0.0491 - val_loss: 0.0521 - 249ms/epoch - 4ms/step
# Epoch 5/150
# 66/66 - 0s - loss: 0.0453 - val_loss: 0.0486 - 259ms/epoch - 4ms/step
# Epoch 6/150
# 66/66 - 0s - loss: 0.0425 - val_loss: 0.0465 - 212ms/epoch - 3ms/step
# Epoch 7/150
# 66/66 - 0s - loss: 0.0406 - val_loss: 0.0452 - 235ms/epoch - 4ms/step
# Epoch 8/150
# 66/66 - 0s - loss: 0.0394 - val_loss: 0.0443 - 237ms/epoch - 4ms/step
# Epoch 9/150
# 66/66 - 0s - loss: 0.0385 - val_loss: 0.0436 - 220ms/epoch - 3ms/step
# Epoch 10/150
# 66/66 - 0s - loss: 0.0379 - val_loss: 0.0431 - 238ms/epoch - 4ms/step
# Epoch 11/150
# 66/66 - 0s - loss: 0.0374 - val_loss: 0.0427 - 215ms/epoch - 3ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av']))
print('Test Temp_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av']))
print('Test NOx_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_av'], df_test_y['CO_av']))
print('Test CO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av']))
print('Test Chuva_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av']))
print('Test Pres_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av']))
print('Test Vel_Vento_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av']))
print('Test SO2_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av']))
print('Test PM10_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_av'], df_test_y['O3_av']))
print('Test O3_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_av'], df_test_y['UR_av']))
print('Test UR_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_av'], df_test_y['NO_av']))
print('Test NO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av']))
print('Test NO2_av RMSE: %.3f' % rmse)
# Out:
# Test Temp_av RMSE: 3.081
# Test NOx_av RMSE: 19.182
# Test CO_av RMSE: 0.210
# Test Chuva_av RMSE: 0.825
# Test Pres_av RMSE: 3.577
# Test Vel_Vento_av RMSE: 0.306
# Test SO2_av RMSE: 4.376
# Test PM10_av RMSE: 20.061
# Test O3_av RMSE: 12.677
# Test UR_av RMSE: 7.114
# Test NO_av RMSE: 13.503
# Test NO2_av RMSE: 12.456

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av MAE: %.3f' % mae)
# Out:
# Test Temp_av MAE: 2.429
# Test NOx_av MAE: 12.523
# Test CO_av MAE: 0.176
# Test Chuva_av MAE: 0.580
# Test Pres_av MAE: 2.922
# Test Vel_Vento_av MAE: 0.255
# Test SO2_av MAE: 3.595
# Test PM10_av MAE: 16.246
# Test O3_av MAE: 10.230
# Test UR_av MAE: 5.407
# Test NO_av MAE: 8.616
# Test NO2_av MAE: 8.960

# %%
r2=r2_score(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av R2: %.3f' % r2)
# Out:
# Test Temp_av R2: 0.189
# Test NOx_av R2: 0.599
# Test CO_av R2: -3.605
# Test Chuva_av R2: -3.733
# Test Pres_av R2: 0.191
# Test Vel_Vento_av R2: -5.848
# Test SO2_av R2: -2.764
# Test PM10_av R2: -0.916
# Test O3_av R2: -1.403
# Test UR_av R2: -1.075
# Test NO_av R2: 0.370
# Test NO2_av R2: 0.522

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 5/5 da divisão

# %%
reframed = series_to_supervised(df_av_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:3168]

# split into train and test sets
values = reframed.values
n_train_days = 2640

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 83/83 - 3s - loss: 0.0903 - val_loss: 0.0737 - 3s/epoch - 32ms/step
# Epoch 2/150
# 83/83 - 0s - loss: 0.0512 - val_loss: 0.0598 - 258ms/epoch - 3ms/step
# Epoch 3/150
# 83/83 - 0s - loss: 0.0451 - val_loss: 0.0524 - 267ms/epoch - 3ms/step
# Epoch 4/150
# 83/83 - 0s - loss: 0.0419 - val_loss: 0.0471 - 278ms/epoch - 3ms/step
# Epoch 5/150
# 83/83 - 0s - loss: 0.0399 - val_loss: 0.0435 - 283ms/epoch - 3ms/step
# Epoch 6/150
# 83/83 - 0s - loss: 0.0384 - val_loss: 0.0409 - 281ms/epoch - 3ms/step
# Epoch 7/150
# 83/83 - 0s - loss: 0.0374 - val_loss: 0.0389 - 280ms/epoch - 3ms/step
# Epoch 8/150
# 83/83 - 0s - loss: 0.0366 - val_loss: 0.0374 - 276ms/epoch - 3ms/step
# Epoch 9/150
# 83/83 - 0s - loss: 0.0360 - val_loss: 0.0363 - 254ms/epoch - 3ms/step
# Epoch 10/150
# 83/83 - 0s - loss: 0.0355 - val_loss: 0.0354 - 283ms/epoch - 3ms/step
# Epoch 11/150
# 83/83 - 0s - loss: 0.0352 - val_loss: 0.0348 - 264ms/epoch - 3ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av']))
print('Test Temp_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av']))
print('Test NOx_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_av'], df_test_y['CO_av']))
print('Test CO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av']))
print('Test Chuva_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av']))
print('Test Pres_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av']))
print('Test Vel_Vento_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av']))
print('Test SO2_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av']))
print('Test PM10_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_av'], df_test_y['O3_av']))
print('Test O3_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_av'], df_test_y['UR_av']))
print('Test UR_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_av'], df_test_y['NO_av']))
print('Test NO_av RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av']))
print('Test NO2_av RMSE: %.3f' % rmse)
# Out:
# Test Temp_av RMSE: 3.529
# Test NOx_av RMSE: 15.215
# Test CO_av RMSE: 0.209
# Test Chuva_av RMSE: 0.961
# Test Pres_av RMSE: 2.773
# Test Vel_Vento_av RMSE: 0.281
# Test SO2_av RMSE: 4.098
# Test PM10_av RMSE: 16.579
# Test O3_av RMSE: 12.971
# Test UR_av RMSE: 6.537
# Test NO_av RMSE: 9.271
# Test NO2_av RMSE: 6.604

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av MAE: %.3f' % mae)
# Out:
# Test Temp_av MAE: 2.780
# Test NOx_av MAE: 12.879
# Test CO_av MAE: 0.183
# Test Chuva_av MAE: 0.700
# Test Pres_av MAE: 2.118
# Test Vel_Vento_av MAE: 0.233
# Test SO2_av MAE: 3.408
# Test PM10_av MAE: 14.023
# Test O3_av MAE: 10.349
# Test UR_av MAE: 5.175
# Test NO_av MAE: 8.222
# Test NO2_av MAE: 5.230

# %%
r2=r2_score(df_inv_yhat['Temp_av'], df_test_y['Temp_av'])
print('Test Temp_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_av'], df_test_y['NOx_av'])
print('Test NOx_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_av'], df_test_y['CO_av'])
print('Test CO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_av'], df_test_y['Chuva_av'])
print('Test Chuva_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_av'], df_test_y['Pres_av'])
print('Test Pres_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_av'], df_test_y['Vel_Vento_av'])
print('Test Vel_Vento_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_av'], df_test_y['SO2_av'])
print('Test SO2_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_av'], df_test_y['PM10_av'])
print('Test PM10_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_av'], df_test_y['O3_av'])
print('Test O3_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_av'], df_test_y['UR_av'])
print('Test UR_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_av'], df_test_y['NO_av'])
print('Test NO_av R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_av'], df_test_y['NO2_av'])
print('Test NO2_av R2: %.3f' % r2)
# Out:
# Test Temp_av R2: -1.203
# Test NOx_av R2: -1.250
# Test CO_av R2: -10.649
# Test Chuva_av R2: -2.701
# Test Pres_av R2: 0.389
# Test Vel_Vento_av R2: -7.722
# Test SO2_av R2: -4.149
# Test PM10_av R2: -0.425
# Test O3_av R2: -1.717
# Test UR_av R2: -0.997
# Test NO_av R2: -0.740
# Test NO2_av R2: 0.028

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# # links sobre hiperparâmetros de redes neurais recorrentes SimpleRNN

# %%
'''
O que foi feito nesta etapa:
----------------------------

Nesta etapa, com intuito de conseguir o melhor modelo, pesquisei sobre os hiperparâmetros que compõem as redes SimpleRNN.
Abaixo seguem os links que salvei da pesquisa

'''

# %% [markdown]
# **-ativação (x)**
# https://keras.io/api/layers/activations/
# https://machinelearningmastery.com/choose-an-activation-function-for-deep-learning/
# https://medium.com/@snaily16/what-why-and-which-activation-functions-b2bf748c0441
# http://kth.diva-portal.org/smash/get/diva2:1465073/FULLTEXT01.pdf
#
# **-diferença entre ativação e recurrent_activation (x)**:
# https://stackoverflow.com/questions/44947842/can-someone-explain-to-me-the-difference-between-activation-and-recurrent-activa
#
# **-significado dos layers:(x)**
# https://stackoverflow.com/questions/57414387/meaning-of-tf-keras-layers-SimpleRNN-parameters
# https://machinelearningmastery.com/use-dropout-SimpleRNN-networks-time-series-forecasting/
#
# **-kernel initializer:(x)**
# https://keras.io/api/layers/initializers/
# https://towardsdatascience.com/weight-initialization-techniques-in-neural-networks-26c649eb3b78
# https://wandb.ai/sayakpaul/weight-initialization-tb/reports/Effects-of-Weight-Initialization-on-Neural-Networks--Vmlldzo2ODY0NA
#
# **-recurrent initializer:(x)**
# https://stackoverflow.com/questions/63630659/what-does-recurrent-initializer-do
# https://notebook.community/infilect/ml-course1/deep-learning-keras/keras-notebooks/RNN/7.1%20RNN%20and%20SimpleRNN
# https://stackoverflow.com/questions/64881855/kernel-and-recurrent-kernel-in-keras-SimpleRNNs
#
# **-bias initializer:(x)**
# https://www.tutorialexample.com/understand-SimpleRNN-weight-and-bias-initialization-when-initializer-is-none-in-tensorflow-tensorflow-tutorial/
# https://medium.com/@glenmeyerowitz/bias-initialization-in-a-neural-network-2e5d26fed0f0
# https://cs231n.github.io/neural-networks-2/
#
#
# **-kernel regularizer:(x)**
# https://machinelearningmastery.com/use-weight-regularization-SimpleRNN-networks-time-series-forecasting/ https://stats.stackexchange.com/questions/164876/what-is-the-trade-off-between-batch-size-and-number-of-iterations-to-train-a-neu https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/
#
# **-bias regularizer:(x)**
# https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-learning-with-weight-regularization/
#
# **-activity regularizer:(x)**
# https://machinelearningmastery.com/how-to-reduce-generalization-error-in-deep-neural-networks-with-activity-regularization-in-keras/
#
# **-kernel constraint:(x)**
# https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-neural-networks-with-weight-constraints-in-keras/
#
# **-dropout:(x)**
# https://machinelearningmastery.com/how-to-reduce-overfitting-with-dropout-regularization-in-keras/
#
# **-recurrent dropout:(x)**
# https://stackoverflow.com/questions/44924690/keras-the-difference-between-SimpleRNN-dropout-and-SimpleRNN-recurrent-dropout
#
# **-return sequences/states:(x)**
# https://machinelearningmastery.com/return-sequences-and-return-states-for-SimpleRNNs-in-keras/
# https://www.dlology.com/blog/how-to-use-return_state-or-return_sequences-in-keras/
#
# **-go backwards:(x)**
# https://stackoverflow.com/questions/49946942/keras-SimpleRNN-go-backwards-usage
#
# **-stateful:(x)**
# https://machinelearningmastery.com/stateful-stateless-SimpleRNN-time-series-forecasting-python/
# https://stackoverflow.com/questions/39681046/keras-stateful-vs-stateless-SimpleRNNs
#
# **-time_major:(x)**
# https://stackoverflow.com/questions/42130491/batch-major-vs-time-major-SimpleRNN
#
# **-unroll:(x)**
# https://machinelearningmastery.com/rnn-unrolling/
# https://stats.stackexchange.com/questions/492040/what-is-unrolling-in-SimpleRNN

# %% [markdown]
# número de neurônios e camadas escondidas

# %%
#https://www.temjournal.com/content/94/TEMJournalNovember2020_1320_1329.pdf *
#https://machinelearningmastery.com/how-to-configure-the-number-of-layers-and-nodes-in-a-neural-network/ *
#https://www.researchgate.net/post/How-to-decide-the-number-of-hidden-layers-and-nodes-in-a-hidden-layer
#https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw *
#https://towardsdatascience.com/beginners-ask-how-many-hidden-layers-neurons-to-use-in-artificial-neural-networks-51466afa0d3e
#https://www.linkedin.com/pulse/choosing-number-hidden-layers-neurons-neural-networks-sachdev/ *
#https://www.hindawi.com/journals/mpe/2013/425740/

# %%
#primeira fórmula: raiz do numero de input * numero de output (testar outras)
