# %% [markdown]
# Obs: falta gerar os notebooks para GRU, LSTM e bi-LSTM

# %%
from google.colab import drive #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
drive.mount('/content/gdrive')
from IPython.display import Image
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## (teoria) validação cruzada- método 2- split cross validation

# %%
Image("gdrive/My Drive/dissertação/split.png")
# Image("split.png") #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ##pré-processamento dos dados

# %%
# df_ca_new = pd.read_csv("gdrive/My Drive/dissertação/df_ca_new.csv",sep=",") #######!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! 29-08
# df_ca_new=pd.read_csv("gdrive/My Drive/dissertação/df_ca_new.csv",sep=",")
# df_ca_new = pd.read_csv("gdrive/My Drive/df_ca_new.csv",sep=",")
# df_ca_new = pd.read_csv("gdrive/My Drive/df_ca_new.csv",sep=",")

# %%
# #dados da estação de São Cristóvão
# df_ca_new=pd.read_csv('df_ca_new.csv')
# #dados da estação da Tijuca
# df_ca_new=pd.read_csv('df_ca_new.csv')


#df_ca_new = pd.read_csv("gdrive/My Drive/dissertação/df_ca_new.csv",sep=",") #######!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! 29-08
# df_ca_new=pd.read_csv("gdrive/My Drive/dissertação/df_ca_new.csv",sep=",")
df_ca_new = pd.read_csv("gdrive/My Drive/df_ca_new.csv",sep=",")
# df_ca_new=pd.read_csv("gdrive/My Drive/dissertação/df_ca_new.csv",sep=",")

# Temp_ca ############################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!29-08
def change_Temp_ca(value):
    if value>=24.423311+3*5.603599:
        value=None
    return value

# NOx_ca
def change_NOx_ca(value):
    if value>=57.234630+3*35.907004:
        value=None
    return value
        
# CO_ca
def change_CO_ca(value):
    if value>=0.401673+3*0.252008:
        value=None
    return value
        
# Chuva_ca
def change_Chuva_ca(value):
    if value>=0.150513+3*3.706666:
        value=None
    return value

# Pres_ca
def change_Pres_ca(value):
    if value>=1015.098704+3*5.385422:
        value=None
    return value
        
# Vel_Vento_ca
def change_Vel_Vento_ca(value):
    if value>=0.736632+3*1.122239:
        value=None
    return value
        
# SO2_ca
def change_SO2_ca(value):
    if value>=3.773778+3*5.782657:
        value=None
    return value

# PM10_ca
def change_PM10_ca(value):
    if value>=32.948537+3*18.924257:
        value=None
    return value
        
# O3_ca
def change_O3_ca(value):
    if value>=28.366178+3*24.830731:
        value=None
    return value
        
# UR_ca
def change_UR_ca(value):
    if value>=65.757445+3*19.398027:
        value=None
    return value

# NO_ca 
def change_NO_ca(value):
    if value>=33.860255+3*25.161391:
        value=None
    return value
        
# NO2_ca
def change_NO2_ca(value):
    if value>=40.879302+3*23.167150:
        value=None
    return value

df_ca_new['Temp_ca']=df_ca_new['Temp_ca'].apply(change_Temp_ca)
df_ca_new['NOx_ca']=df_ca_new['NOx_ca'].apply(change_NOx_ca)
df_ca_new['CO_ca']=df_ca_new['CO_ca'].apply(change_CO_ca)
df_ca_new['Chuva_ca']=df_ca_new['Chuva_ca'].apply(change_Chuva_ca)
df_ca_new['Pres_ca']=df_ca_new['Pres_ca'].apply(change_Pres_ca)
df_ca_new['Vel_Vento_ca']=df_ca_new['Vel_Vento_ca'].apply(change_Vel_Vento_ca)
df_ca_new['SO2_ca']=df_ca_new['SO2_ca'].apply(change_SO2_ca)
df_ca_new['PM10_ca']=df_ca_new['PM10_ca'].apply(change_PM10_ca)
df_ca_new['O3_ca']=df_ca_new['O3_ca'].apply(change_O3_ca)
df_ca_new['UR_ca']=df_ca_new['UR_ca'].apply(change_UR_ca)
df_ca_new['NO_ca']=df_ca_new['NO_ca'].apply(change_NO_ca)
df_ca_new['NO2_ca']=df_ca_new['NO2_ca'].apply(change_NO2_ca)

df_ca_new.interpolate(method='linear', inplace=True)

# # ------------------------------------------------------------------------------------------


# # Temp_ca #############################################29-08
# def change_Temp_ca(value):
#     if value>= 26.511795+3*4.771902:
#         value=None
#     return value

# # NOx_ca
# def change_NOx_ca(value):
#     if value>=57.234630+3*35.907004:
#         value=None
#     return value
        
# # CO_ca
# def change_CO_ca(value):
#     if value>=0.241478+3*0.321004:
#         value=None
#     return value
        
# # Chuva_ca
# def change_Chuva_ca(value):
#     if value>=0.105082+3*0.965220:
#         value=None
#     return value

# # Pres_ca
# def change_Pres_ca(value):
#     if value>=1014.916328+3*4.810906:
#         value=None
#     return value
        
# # Vel_Vento_ca
# def change_Vel_Vento_ca(value):
#     if value>=0.891624+3*0.582975:
#         value=None
#     return value
        
# # SO2_ca
# def change_SO2_ca(value):
#     if value>=7.672783+3*9.602003:
#         value=None
#     return value

# # PM10_ca
# def change_PM10_ca(value):
#     if value>=34.386848+3*21.806007:
#         value=None
#     return value
        
# # O3_ca
# def change_O3_ca(value):
#     if value>=24.037099+3*26.548084:
#         value=None
#     return value
        
# # UR_ca
# def change_UR_ca(value):
#     if value>=72.125128+3*17.142190:
#         value=None
#     return value

# # NO_ca 
# def change_NO_ca(value):
#     if value>=33.860255+3*25.161391:
#         value=None
#     return value
        
# # NO2_ca
# def change_NO2_ca(value):
#     if value>=40.879302+3*23.167150:
#         value=None
#     return value

# df_ca_new['Temp_ca']=df_ca_new['Temp_ca'].apply(change_Temp_ca)
# df_ca_new['NOx_ca']=df_ca_new['NOx_ca'].apply(change_NOx_ca)
# df_ca_new['CO_ca']=df_ca_new['CO_ca'].apply(change_CO_ca)
# df_ca_new['Chuva_ca']=df_ca_new['Chuva_ca'].apply(change_Chuva_ca)
# df_ca_new['Pres_ca']=df_ca_new['Pres_ca'].apply(change_Pres_ca)
# df_ca_new['Vel_Vento_ca']=df_ca_new['Vel_Vento_ca'].apply(change_Vel_Vento_ca)
# df_ca_new['SO2_ca']=df_ca_new['SO2_ca'].apply(change_SO2_ca)
# df_ca_new['PM10_ca']=df_ca_new['PM10_ca'].apply(change_PM10_ca)
# df_ca_new['O3_ca']=df_ca_new['O3_ca'].apply(change_O3_ca)
# df_ca_new['UR_ca']=df_ca_new['UR_ca'].apply(change_UR_ca)
# df_ca_new['NO_ca']=df_ca_new['NO_ca'].apply(change_NO_ca)
# df_ca_new['NO2_ca']=df_ca_new['NO2_ca'].apply(change_NO2_ca)

# df_ca_new.interpolate(method='linear', inplace=True)

# --------------------------------------------------------------------------------------------

# # Temp_ca
# def change_Temp_ca(value):
#     if value>=25.302538+3*4.229583:
#         value=None
#     return value

# # NOx_ca
# def change_NOx_ca(value):
#     if value>=57.234630+3*35.907004:
#         value=None
#     return value
        
# # CO_ca
# def change_CO_ca(value):
#     if value>=0.153159+3*0.203797:
#         value=None
#     return value
        
# # Chuva_ca
# def change_Chuva_ca(value):
#     if value>=0.128912+3*1.086669:
#         value=None
#     return value

# # Pres_ca
# def change_Pres_ca(value):
#     if value>=1015.123242+3*4.814236:
#         value=None
#     return value
        
# # Vel_Vento_ca
# def change_Vel_Vento_ca(value):
#     if value>=0.745700+3*0.576142:
#         value=None
#     return value
        
# # SO2_ca
# def change_SO2_ca(value):
#     if value>=3.590011+3*5.180285:
#         value=None
#     return value

# # PM10_ca
# def change_PM10_ca(value):
#     if value>=53.253891+3*22.291911:
#         value=None
#     return value
        
# # O3_ca
# def change_O3_ca(value):
#     if value>=20.866469+3*17.741608:
#         value=None
#     return value
        
# # UR_ca
# def change_UR_ca(value):
#     if value>=72.190543+3*15.100447:
#         value=None
#     return value

# # NO_ca 
# def change_NO_ca(value):
#     if value>=33.860255+3*25.161391:
#         value=None
#     return value
        
# # NO2_ca
# def change_NO2_ca(value):
#     if value>=40.879302+3*23.167150:
#         value=None
#     return value

# df_ca_new['Temp_ca']=df_ca_new['Temp_ca'].apply(change_Temp_ca)
# df_ca_new['NOx_ca']=df_ca_new['NOx_ca'].apply(change_NOx_ca)
# df_ca_new['CO_ca']=df_ca_new['CO_ca'].apply(change_CO_ca)
# df_ca_new['Chuva_ca']=df_ca_new['Chuva_ca'].apply(change_Chuva_ca)
# df_ca_new['Pres_ca']=df_ca_new['Pres_ca'].apply(change_Pres_ca)
# df_ca_new['Vel_Vento_ca']=df_ca_new['Vel_Vento_ca'].apply(change_Vel_Vento_ca)
# df_ca_new['SO2_ca']=df_ca_new['SO2_ca'].apply(change_SO2_ca)
# df_ca_new['PM10_ca']=df_ca_new['PM10_ca'].apply(change_PM10_ca)
# df_ca_new['O3_ca']=df_ca_new['O3_ca'].apply(change_O3_ca)
# df_ca_new['UR_ca']=df_ca_new['UR_ca'].apply(change_UR_ca)
# df_ca_new['NO_ca']=df_ca_new['NO_ca'].apply(change_NO_ca)
# df_ca_new['NO2_ca']=df_ca_new['NO2_ca'].apply(change_NO2_ca)

# df_ca_new.interpolate(method='linear', inplace=True)

# # ----------------------------------------------------------------------------------------

# # Temp_ca
# def change_Temp_ca(value):
#     if value>=25.180673+3*4.516643:
#         value=None
#     return value

# # NOx_ca
# def change_NOx_ca(value):
#     if value>=57.234630+3*35.907004:
#         value=None
#     return value
        
# # CO_ca
# def change_CO_ca(value):
#     if value>=0.400990+3*0.254931:
#         value=None
#     return value
        
# # Chuva_ca
# def change_Chuva_ca(value):
#     if value>=0.116201+3*1.010423:
#         value=None
#     return value

# # Pres_ca
# def change_Pres_ca(value):
#     if value>=1014.854482+3*4.792065:
#         value=None
#     return value
        
# # Vel_Vento_ca
# def change_Vel_Vento_ca(value):
#     if value>=0.991521+3*0.762128:
#         value=None
#     return value
        
# # SO2_ca
# def change_SO2_ca(value):
#     if value>=5.026369+3*6.266349:
#         value=None
#     return value

# # PM10_ca
# def change_PM10_ca(value):
#     if value>=32.947192+3*18.505545:
#         value=None
#     return value
        
# # O3_ca
# def change_O3_ca(value):
#     if value>=21.543544+3*22.057785:
#         value=None
#     return value
        
# # UR_ca
# def change_UR_ca(value):
#     if value>=68.982944+3*16.276184:
#         value=None
#     return value

# # NO_ca 
# def change_NO_ca(value):
#     if value>=33.860255+3*25.161391:
#         value=None
#     return value
        
# # NO2_ca
# def change_NO2_ca(value):
#     if value>=40.879302+3*23.167150:
#         value=None
#     return value

# df_ca_new['Temp_ca']=df_ca_new['Temp_ca'].apply(change_Temp_ca)
# df_ca_new['NOx_ca']=df_ca_new['NOx_ca'].apply(change_NOx_ca)
# df_ca_new['CO_ca']=df_ca_new['CO_ca'].apply(change_CO_ca)
# df_ca_new['Chuva_ca']=df_ca_new['Chuva_ca'].apply(change_Chuva_ca)
# df_ca_new['Pres_ca']=df_ca_new['Pres_ca'].apply(change_Pres_ca)
# df_ca_new['Vel_Vento_ca']=df_ca_new['Vel_Vento_ca'].apply(change_Vel_Vento_ca)
# df_ca_new['SO2_ca']=df_ca_new['SO2_ca'].apply(change_SO2_ca)
# df_ca_new['PM10_ca']=df_ca_new['PM10_ca'].apply(change_PM10_ca)
# df_ca_new['O3_ca']=df_ca_new['O3_ca'].apply(change_O3_ca)
# df_ca_new['UR_ca']=df_ca_new['UR_ca'].apply(change_UR_ca)
# df_ca_new['NO_ca']=df_ca_new['NO_ca'].apply(change_NO_ca)
# df_ca_new['NO2_ca']=df_ca_new['NO2_ca'].apply(change_NO2_ca)

# df_ca_new.interpolate(method='linear', inplace=True)

# # ----------------------------------------------------------------------------------------

# df_ca_new.reset_index(inplace=True) ######!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!29-8

# df_ca_new['data_resolved']=df_ca_new['Data'].apply(lambda x: str(x)[:10])

# df_ca_new = df_ca_new[['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
#        'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca','data_resolved']]

# df_ca_new = df_ca_new.groupby(['data_resolved'], sort=False)['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
#        'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca'].max()

# names = df_ca_new.columns

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# data_scaled = scaler.fit_transform(df_ca_new)

# df_ca_new_scaled = pd.DataFrame(data_scaled, columns=names)

# df_ca_new_scaled.index=df_ca_new.index

# -----------------------------------------------------------------------------------------------

df_ca_new.reset_index(inplace=True) #######################29-08

df_ca_new['data_resolved']=df_ca_new['Data'].apply(lambda x: str(x)[:10])

df_ca_new = df_ca_new[['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
       'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca','data_resolved']]

df_ca_new = df_ca_new.groupby(['data_resolved'], sort=False)['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
       'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca'].max()

names = df_ca_new.columns

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() 
data_scaled = scaler.fit_transform(df_ca_new)

df_ca_new_scaled = pd.DataFrame(data_scaled, columns=names)

df_ca_new_scaled.index=df_ca_new.index

# # -------------------------------------------------------------------------------------------------

# df_ca_new.reset_index(inplace=True) #######################29-08

# df_ca_new['data_resolved']=df_ca_new['Data'].apply(lambda x: str(x)[:10])

# df_ca_new = df_ca_new[['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
#        'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca','data_resolved']]

# df_ca_new = df_ca_new.groupby(['data_resolved'], sort=False)['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
#        'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca'].max()

# names = df_ca_new.columns

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# data_scaled = scaler.fit_transform(df_ca_new)

# df_ca_new_scaled = pd.DataFrame(data_scaled, columns=names)

# df_ca_new_scaled.index=df_ca_new.index

# # -------------------------------------------------------------------------------------------------

# df_ca_new.reset_index(inplace=True) #######################29-08

# df_ca_new['data_resolved']=df_ca_new['Data'].apply(lambda x: str(x)[:10])

# df_ca_new = df_ca_new[['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
#        'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca','data_resolved']]

# df_ca_new = df_ca_new.groupby(['data_resolved'], sort=False)['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca',
#        'Vel_Vento_ca', 'SO2_ca', 'PM10_ca', 'O3_ca', 'UR_ca','NO_ca','NO2_ca'].max()

# names = df_ca_new.columns

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# data_scaled = scaler.fit_transform(df_ca_new)

# df_ca_new_scaled = pd.DataFrame(data_scaled, columns=names)

# df_ca_new_scaled.index=df_ca_new.index

# # -------------------------------------------------------------------------------------------------

import time
import pandas as pd
import seaborn as sns
import missingno as msno
import warnings
import statistics
from matplotlib import pyplot as plt
import datetime
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',100)

from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score #colocar citação

from math import sqrt
from numpy import concatenate
from matplotlib import pyplot

from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM, GRU,SimpleRNN,Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed

values = df_ca_new_scaled.values
values = values.astype('float32')

# convert series to supervised learning
def series_to_supervised(data, n_in=10, n_out=10, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# specify the number of lag hours
n_days = 7 #input
n_features = 12 #12 colunas !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! 29-08

#reframed = series_to_supervised(df_ca_new_scaled, n_days, 1) # quebrar aqui

# %% [markdown]
# ## Teste de bacth e epoch

# %% [markdown]
# **listas para salvar rmse**

# %%
lista_Temp_ca_RMSE=[]
lista_NOx_ca_RMSE=[]
lista_CO_ca_RMSE=[]
lista_Chuva_ca_RMSE=[]
lista_Pres_ca_RMSE=[]
lista_Vel_Vento_ca_RMSE=[]
lista_SO2_ca_RMSE=[]
lista_PM10_ca_RMSE=[]
lista_O3_ca_RMSE=[]
lista_UR_ca_RMSE=[]
lista_NO_ca_RMSE=[]
lista_NO2_ca_RMSE=[]

# %% [markdown]
# #### treinamento do modelo para primeiro 1/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1056]

# split into train and test sets
values = reframed.values
n_train_days = 528

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(GRU(64,return_sequences=True))
# model.add(GRU(64,return_sequences=True))
# model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 17/17 - 8s - loss: 0.3077 - val_loss: 0.3016 - 8s/epoch - 445ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.2067 - val_loss: 0.1375 - 287ms/epoch - 17ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0771 - val_loss: 0.0747 - 304ms/epoch - 18ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0463 - val_loss: 0.0719 - 301ms/epoch - 18ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0427 - val_loss: 0.0688 - 247ms/epoch - 15ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0422 - val_loss: 0.0669 - 302ms/epoch - 18ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0418 - val_loss: 0.0670 - 306ms/epoch - 18ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0417 - val_loss: 0.0667 - 233ms/epoch - 14ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0415 - val_loss: 0.0662 - 292ms/epoch - 17ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0413 - val_loss: 0.0658 - 228ms/epoch - 13ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0412 - val_loss: 0.0653 - 282ms/epoch - 17ms/step
# Epoch 12/150
# ...

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=False) #64 é o numero de neurônios

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 1, 84)             56784
#
#  time_distributed_6 (TimeDis  (None, 1, 12)            1020
#  tributed)
#
#  lstm_1 (LSTM)               (None, 1, 64)             19712
#
#  time_distributed_7 (TimeDis  (None, 1, 12)            780
#  tributed)
#
# ...
# Total params: 78,296
# Trainable params: 78,296
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 2/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1584]

# split into train and test sets
values = reframed.values
n_train_days = 1056

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 3/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2112]

# split into train and test sets
values = reframed.values
n_train_days = 1584

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 4/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2640]

# split into train and test sets
values = reframed.values
n_train_days = 2112

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 5/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:3168]

# split into train and test sets
values = reframed.values
n_train_days = 2640

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# **resultados finais**

# %%
RMSE_RNN_Temp_ca=statistics.mean(lista_Temp_ca_RMSE)
RMSE_RNN_NOx_ca=statistics.mean(lista_NOx_ca_RMSE)
RMSE_RNN_CO_ca=statistics.mean(lista_CO_ca_RMSE)
RMSE_RNN_Chuva_ca=statistics.mean(lista_Chuva_ca_RMSE)
RMSE_RNN_Pres_ca=statistics.mean(lista_Pres_ca_RMSE)
RMSE_RNN_Vel_Vento_ca=statistics.mean(lista_Vel_Vento_ca_RMSE)
RMSE_RNN_SO2_ca=statistics.mean(lista_SO2_ca_RMSE)
RMSE_RNN_PM10_ca=statistics.mean(lista_PM10_ca_RMSE)
RMSE_RNN_O3_ca=statistics.mean(lista_O3_ca_RMSE)
RMSE_RNN_UR_ca=statistics.mean(lista_UR_ca_RMSE)
RMSE_RNN_NO_ca=statistics.mean(lista_NO_ca_RMSE)
RMSE_RNN_NO2_ca=statistics.mean(lista_NO2_ca_RMSE)

# %% [markdown]
# ## Long-Short Term Memory

# %% [markdown]
# **listas para salvar rmse**

# %%
lista_Temp_ca_RMSE=[]
lista_NOx_ca_RMSE=[]
lista_CO_ca_RMSE=[]
lista_Chuva_ca_RMSE=[]
lista_Pres_ca_RMSE=[]
lista_Vel_Vento_ca_RMSE=[]
lista_SO2_ca_RMSE=[]
lista_PM10_ca_RMSE=[]
lista_O3_ca_RMSE=[]
lista_UR_ca_RMSE=[]
lista_NO_ca_RMSE=[]
lista_NO2_ca_RMSE=[]

# %% [markdown]
# #### treinamento do modelo para primeiro 1/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1056]

# split into train and test sets
values = reframed.values
n_train_days = 528

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 17/17 - 12s - loss: 0.2979 - val_loss: 0.2869 - 12s/epoch - 694ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.1795 - val_loss: 0.1224 - 197ms/epoch - 12ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0649 - val_loss: 0.0744 - 277ms/epoch - 16ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0443 - val_loss: 0.0675 - 243ms/epoch - 14ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0424 - val_loss: 0.0673 - 202ms/epoch - 12ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0419 - val_loss: 0.0672 - 206ms/epoch - 12ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0417 - val_loss: 0.0668 - 181ms/epoch - 11ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0416 - val_loss: 0.0664 - 303ms/epoch - 18ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0415 - val_loss: 0.0662 - 292ms/epoch - 17ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0413 - val_loss: 0.0660 - 294ms/epoch - 17ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0412 - val_loss: 0.0657 - 285ms/epoch - 17ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.517
# Test NOx_ca RMSE: 28.296
# Test CO_ca RMSE: 0.237
# Test Chuva_ca RMSE: 0.769
# Test Pres_ca RMSE: 3.220
# Test Vel_Vento_ca RMSE: 0.525
# Test SO2_ca RMSE: 5.748
# Test PM10_ca RMSE: 15.729
# Test O3_ca RMSE: 17.400
# Test UR_ca RMSE: 6.867
# Test NO_ca RMSE: 17.295
# Test NO2_ca RMSE: 17.519

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.819
# Test NOx_ca MAE: 22.027
# Test CO_ca MAE: 0.196
# Test Chuva_ca MAE: 0.480
# Test Pres_ca MAE: 2.538
# Test Vel_Vento_ca MAE: 0.426
# Test SO2_ca MAE: 4.692
# Test PM10_ca MAE: 12.944
# Test O3_ca MAE: 14.491
# Test UR_ca MAE: 5.482
# Test NO_ca MAE: 13.447
# Test NO2_ca MAE: 13.642

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.476
# Test NOx_ca R2: 0.136
# Test CO_ca R2: -2.255
# Test Chuva_ca R2: -4.257
# Test Pres_ca R2: -0.014
# Test Vel_Vento_ca R2: -6.423
# Test SO2_ca R2: -1.758
# Test PM10_ca R2: -1.295
# Test O3_ca R2: -2.064
# Test UR_ca R2: -2.037
# Test NO_ca R2: 0.118
# Test NO2_ca R2: 0.125

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 2/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1584]

# split into train and test sets
values = reframed.values
n_train_days = 1056

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 33/33 - 7s - loss: 0.2630 - val_loss: 0.1390 - 7s/epoch - 204ms/step
# Epoch 2/150
# 33/33 - 0s - loss: 0.0742 - val_loss: 0.0484 - 342ms/epoch - 10ms/step
# Epoch 3/150
# 33/33 - 0s - loss: 0.0514 - val_loss: 0.0492 - 274ms/epoch - 8ms/step
# Epoch 4/150
# 33/33 - 0s - loss: 0.0497 - val_loss: 0.0487 - 296ms/epoch - 9ms/step
# Epoch 5/150
# 33/33 - 0s - loss: 0.0488 - val_loss: 0.0480 - 264ms/epoch - 8ms/step
# Epoch 6/150
# 33/33 - 0s - loss: 0.0478 - val_loss: 0.0471 - 264ms/epoch - 8ms/step
# Epoch 7/150
# 33/33 - 0s - loss: 0.0466 - val_loss: 0.0460 - 337ms/epoch - 10ms/step
# Epoch 8/150
# 33/33 - 0s - loss: 0.0451 - val_loss: 0.0446 - 350ms/epoch - 11ms/step
# Epoch 9/150
# 33/33 - 0s - loss: 0.0433 - val_loss: 0.0431 - 361ms/epoch - 11ms/step
# Epoch 10/150
# 33/33 - 0s - loss: 0.0413 - val_loss: 0.0419 - 280ms/epoch - 8ms/step
# Epoch 11/150
# 33/33 - 0s - loss: 0.0397 - val_loss: 0.0411 - 343ms/epoch - 10ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.318
# Test NOx_ca RMSE: 26.290
# Test CO_ca RMSE: 0.214
# Test Chuva_ca RMSE: 0.731
# Test Pres_ca RMSE: 2.661
# Test Vel_Vento_ca RMSE: 0.532
# Test SO2_ca RMSE: 5.055
# Test PM10_ca RMSE: 14.858
# Test O3_ca RMSE: 16.423
# Test UR_ca RMSE: 11.524
# Test NO_ca RMSE: 15.668
# Test NO2_ca RMSE: 15.645

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.724
# Test NOx_ca MAE: 20.699
# Test CO_ca MAE: 0.165
# Test Chuva_ca MAE: 0.522
# Test Pres_ca MAE: 2.050
# Test Vel_Vento_ca MAE: 0.436
# Test SO2_ca MAE: 4.065
# Test PM10_ca MAE: 11.867
# Test O3_ca MAE: 13.231
# Test UR_ca MAE: 7.752
# Test NO_ca MAE: 12.505
# Test NO2_ca MAE: 12.433

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: 0.160
# Test NOx_ca R2: -0.120
# Test CO_ca R2: -2.152
# Test Chuva_ca R2: -4.709
# Test Pres_ca R2: 0.548
# Test Vel_Vento_ca R2: -3.043
# Test SO2_ca R2: -1.850
# Test PM10_ca R2: -0.979
# Test O3_ca R2: -0.908
# Test UR_ca R2: -5.788
# Test NO_ca R2: 0.374
# Test NO2_ca R2: 0.428

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 3/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2112]

# split into train and test sets
values = reframed.values
n_train_days = 1584

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 50/50 - 8s - loss: 0.2085 - val_loss: 0.0519 - 8s/epoch - 152ms/step
# Epoch 2/150
# 50/50 - 0s - loss: 0.0528 - val_loss: 0.0453 - 430ms/epoch - 9ms/step
# Epoch 3/150
# 50/50 - 1s - loss: 0.0515 - val_loss: 0.0444 - 540ms/epoch - 11ms/step
# Epoch 4/150
# 50/50 - 1s - loss: 0.0505 - val_loss: 0.0441 - 521ms/epoch - 10ms/step
# Epoch 5/150
# 50/50 - 1s - loss: 0.0497 - val_loss: 0.0436 - 528ms/epoch - 11ms/step
# Epoch 6/150
# 50/50 - 1s - loss: 0.0488 - val_loss: 0.0431 - 539ms/epoch - 11ms/step
# Epoch 7/150
# 50/50 - 1s - loss: 0.0477 - val_loss: 0.0426 - 518ms/epoch - 10ms/step
# Epoch 8/150
# 50/50 - 0s - loss: 0.0463 - val_loss: 0.0420 - 469ms/epoch - 9ms/step
# Epoch 9/150
# 50/50 - 1s - loss: 0.0445 - val_loss: 0.0413 - 524ms/epoch - 10ms/step
# Epoch 10/150
# 50/50 - 0s - loss: 0.0422 - val_loss: 0.0405 - 470ms/epoch - 9ms/step
# Epoch 11/150
# 50/50 - 1s - loss: 0.0396 - val_loss: 0.0396 - 530ms/epoch - 11ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.162
# Test NOx_ca RMSE: 30.332
# Test CO_ca RMSE: 0.227
# Test Chuva_ca RMSE: 0.786
# Test Pres_ca RMSE: 2.580
# Test Vel_Vento_ca RMSE: 0.498
# Test SO2_ca RMSE: 5.386
# Test PM10_ca RMSE: 13.634
# Test O3_ca RMSE: 15.328
# Test UR_ca RMSE: 7.086
# Test NO_ca RMSE: 20.962
# Test NO2_ca RMSE: 17.921

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.486
# Test NOx_ca MAE: 24.158
# Test CO_ca MAE: 0.181
# Test Chuva_ca MAE: 0.563
# Test Pres_ca MAE: 2.009
# Test Vel_Vento_ca MAE: 0.404
# Test SO2_ca MAE: 4.443
# Test PM10_ca MAE: 10.892
# Test O3_ca MAE: 12.124
# Test UR_ca MAE: 5.817
# Test NO_ca MAE: 16.373
# Test NO2_ca MAE: 13.552

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: 0.044
# Test NOx_ca R2: -0.262
# Test CO_ca R2: -2.616
# Test Chuva_ca R2: -3.508
# Test Pres_ca R2: 0.598
# Test Vel_Vento_ca R2: -4.884
# Test SO2_ca R2: -2.103
# Test PM10_ca R2: -0.430
# Test O3_ca R2: -1.077
# Test UR_ca R2: -1.718
# Test NO_ca R2: -0.168
# Test NO2_ca R2: 0.160

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 4/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2640]

# split into train and test sets
values = reframed.values
n_train_days = 2112

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 66/66 - 7s - loss: 0.1625 - val_loss: 0.0556 - 7s/epoch - 112ms/step
# Epoch 2/150
# 66/66 - 1s - loss: 0.0503 - val_loss: 0.0567 - 519ms/epoch - 8ms/step
# Epoch 3/150
# 66/66 - 0s - loss: 0.0496 - val_loss: 0.0559 - 452ms/epoch - 7ms/step
# Epoch 4/150
# 66/66 - 1s - loss: 0.0487 - val_loss: 0.0547 - 504ms/epoch - 8ms/step
# Epoch 5/150
# 66/66 - 1s - loss: 0.0475 - val_loss: 0.0533 - 525ms/epoch - 8ms/step
# Epoch 6/150
# 66/66 - 1s - loss: 0.0461 - val_loss: 0.0512 - 504ms/epoch - 8ms/step
# Epoch 7/150
# 66/66 - 0s - loss: 0.0441 - val_loss: 0.0481 - 459ms/epoch - 7ms/step
# Epoch 8/150
# 66/66 - 0s - loss: 0.0415 - val_loss: 0.0450 - 435ms/epoch - 7ms/step
# Epoch 9/150
# 66/66 - 0s - loss: 0.0394 - val_loss: 0.0432 - 436ms/epoch - 7ms/step
# Epoch 10/150
# 66/66 - 0s - loss: 0.0382 - val_loss: 0.0421 - 411ms/epoch - 6ms/step
# Epoch 11/150
# 66/66 - 0s - loss: 0.0374 - val_loss: 0.0413 - 441ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.328
# Test NOx_ca RMSE: 26.225
# Test CO_ca RMSE: 0.223
# Test Chuva_ca RMSE: 0.858
# Test Pres_ca RMSE: 2.313
# Test Vel_Vento_ca RMSE: 0.454
# Test SO2_ca RMSE: 5.387
# Test PM10_ca RMSE: 14.035
# Test O3_ca RMSE: 15.904
# Test UR_ca RMSE: 10.289
# Test NO_ca RMSE: 20.926
# Test NO2_ca RMSE: 15.376

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.628
# Test NOx_ca MAE: 20.126
# Test CO_ca MAE: 0.186
# Test Chuva_ca MAE: 0.577
# Test Pres_ca MAE: 1.800
# Test Vel_Vento_ca MAE: 0.367
# Test SO2_ca MAE: 4.465
# Test PM10_ca MAE: 11.348
# Test O3_ca MAE: 13.062
# Test UR_ca MAE: 7.456
# Test NO_ca MAE: 17.182
# Test NO2_ca MAE: 11.393

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.220
# Test NOx_ca R2: 0.149
# Test CO_ca R2: -2.044
# Test Chuva_ca R2: -3.871
# Test Pres_ca R2: 0.497
# Test Vel_Vento_ca R2: -4.857
# Test SO2_ca R2: -2.484
# Test PM10_ca R2: -1.505
# Test O3_ca R2: -0.979
# Test UR_ca R2: -3.692
# Test NO_ca R2: -0.662
# Test NO2_ca R2: 0.411

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 5/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:3168]

# split into train and test sets
values = reframed.values
n_train_days = 2640

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 83/83 - 7s - loss: 0.1485 - val_loss: 0.0500 - 7s/epoch - 89ms/step
# Epoch 2/150
# 83/83 - 1s - loss: 0.0504 - val_loss: 0.0494 - 773ms/epoch - 9ms/step
# Epoch 3/150
# 83/83 - 1s - loss: 0.0495 - val_loss: 0.0490 - 744ms/epoch - 9ms/step
# Epoch 4/150
# 83/83 - 1s - loss: 0.0484 - val_loss: 0.0480 - 754ms/epoch - 9ms/step
# Epoch 5/150
# 83/83 - 1s - loss: 0.0467 - val_loss: 0.0461 - 733ms/epoch - 9ms/step
# Epoch 6/150
# 83/83 - 1s - loss: 0.0442 - val_loss: 0.0437 - 752ms/epoch - 9ms/step
# Epoch 7/150
# 83/83 - 1s - loss: 0.0415 - val_loss: 0.0416 - 703ms/epoch - 8ms/step
# Epoch 8/150
# 83/83 - 1s - loss: 0.0394 - val_loss: 0.0397 - 781ms/epoch - 9ms/step
# Epoch 9/150
# 83/83 - 1s - loss: 0.0379 - val_loss: 0.0383 - 749ms/epoch - 9ms/step
# Epoch 10/150
# 83/83 - 1s - loss: 0.0370 - val_loss: 0.0377 - 749ms/epoch - 9ms/step
# Epoch 11/150
# 83/83 - 1s - loss: 0.0365 - val_loss: 0.0372 - 742ms/epoch - 9ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.599
# Test NOx_ca RMSE: 13.666
# Test CO_ca RMSE: 0.234
# Test Chuva_ca RMSE: 0.803
# Test Pres_ca RMSE: 3.165
# Test Vel_Vento_ca RMSE: 0.569
# Test SO2_ca RMSE: 5.244
# Test PM10_ca RMSE: 14.831
# Test O3_ca RMSE: 15.414
# Test UR_ca RMSE: 6.957
# Test NO_ca RMSE: 8.230
# Test NO2_ca RMSE: 7.644

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.820
# Test NOx_ca MAE: 10.582
# Test CO_ca MAE: 0.190
# Test Chuva_ca MAE: 0.569
# Test Pres_ca MAE: 2.545
# Test Vel_Vento_ca MAE: 0.468
# Test SO2_ca MAE: 4.330
# Test PM10_ca MAE: 12.217
# Test O3_ca MAE: 12.269
# Test UR_ca MAE: 5.154
# Test NO_ca MAE: 6.287
# Test NO2_ca MAE: 5.971

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.428
# Test NOx_ca R2: 0.834
# Test CO_ca R2: -0.555
# Test Chuva_ca R2: -3.663
# Test Pres_ca R2: 0.325
# Test Vel_Vento_ca R2: -5.754
# Test SO2_ca R2: -2.203
# Test PM10_ca R2: -0.500
# Test O3_ca R2: -0.143
# Test UR_ca R2: -0.518
# Test NO_ca R2: 0.856
# Test NO2_ca R2: 0.838

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# **resultados finais**

# %%
RMSE_LSTM_Temp_ca=statistics.mean(lista_Temp_ca_RMSE)
RMSE_LSTM_NOx_ca=statistics.mean(lista_NOx_ca_RMSE)
RMSE_LSTM_CO_ca=statistics.mean(lista_CO_ca_RMSE)
RMSE_LSTM_Chuva_ca=statistics.mean(lista_Chuva_ca_RMSE)
RMSE_LSTM_Pres_ca=statistics.mean(lista_Pres_ca_RMSE)
RMSE_LSTM_Vel_Vento_ca=statistics.mean(lista_Vel_Vento_ca_RMSE)
RMSE_LSTM_SO2_ca=statistics.mean(lista_SO2_ca_RMSE)
RMSE_LSTM_PM10_ca=statistics.mean(lista_PM10_ca_RMSE)
RMSE_LSTM_O3_ca=statistics.mean(lista_O3_ca_RMSE)
RMSE_LSTM_UR_ca=statistics.mean(lista_UR_ca_RMSE)
RMSE_LSTM_NO_ca=statistics.mean(lista_NO_ca_RMSE)
RMSE_LSTM_NO2_ca=statistics.mean(lista_NO2_ca_RMSE)

# %% [markdown]
# ## Gated Recurrent Unity

# %% [markdown]
# **listas para salvar rmse**

# %%
lista_Temp_ca_RMSE=[]
lista_NOx_ca_RMSE=[]
lista_CO_ca_RMSE=[]
lista_Chuva_ca_RMSE=[]
lista_Pres_ca_RMSE=[]
lista_Vel_Vento_ca_RMSE=[]
lista_SO2_ca_RMSE=[]
lista_PM10_ca_RMSE=[]
lista_O3_ca_RMSE=[]
lista_UR_ca_RMSE=[]
lista_NO_ca_RMSE=[]
lista_NO2_ca_RMSE=[]

# %% [markdown]
# #### treinamento do modelo para primeiro 1/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1056]

# split into train and test sets
values = reframed.values
n_train_days = 528

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 17/17 - 7s - loss: 0.2669 - val_loss: 0.2122 - 7s/epoch - 399ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.1022 - val_loss: 0.0883 - 181ms/epoch - 11ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0488 - val_loss: 0.0715 - 192ms/epoch - 11ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0431 - val_loss: 0.0671 - 193ms/epoch - 11ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0423 - val_loss: 0.0662 - 201ms/epoch - 12ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0418 - val_loss: 0.0656 - 277ms/epoch - 16ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0414 - val_loss: 0.0644 - 190ms/epoch - 11ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0411 - val_loss: 0.0632 - 193ms/epoch - 11ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0407 - val_loss: 0.0621 - 205ms/epoch - 12ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0403 - val_loss: 0.0608 - 197ms/epoch - 12ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0399 - val_loss: 0.0594 - 200ms/epoch - 12ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.461
# Test NOx_ca RMSE: 29.108
# Test CO_ca RMSE: 0.248
# Test Chuva_ca RMSE: 0.808
# Test Pres_ca RMSE: 3.165
# Test Vel_Vento_ca RMSE: 0.476
# Test SO2_ca RMSE: 5.935
# Test PM10_ca RMSE: 15.702
# Test O3_ca RMSE: 15.356
# Test UR_ca RMSE: 6.736
# Test NO_ca RMSE: 17.568
# Test NO2_ca RMSE: 17.949

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.784
# Test NOx_ca MAE: 22.794
# Test CO_ca MAE: 0.206
# Test Chuva_ca MAE: 0.519
# Test Pres_ca MAE: 2.494
# Test Vel_Vento_ca MAE: 0.387
# Test SO2_ca MAE: 4.811
# Test PM10_ca MAE: 12.598
# Test O3_ca MAE: 12.588
# Test UR_ca MAE: 5.522
# Test NO_ca MAE: 13.594
# Test NO2_ca MAE: 14.070

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.771
# Test NOx_ca R2: 0.115
# Test CO_ca R2: -2.392
# Test Chuva_ca R2: -3.123
# Test Pres_ca R2: -0.423
# Test Vel_Vento_ca R2: -4.575
# Test SO2_ca R2: -2.084
# Test PM10_ca R2: -0.902
# Test O3_ca R2: -1.369
# Test UR_ca R2: -2.105
# Test NO_ca R2: 0.131
# Test NO2_ca R2: -0.041

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 2/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1584]

# split into train and test sets
values = reframed.values
n_train_days = 1056

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 33/33 - 6s - loss: 0.1942 - val_loss: 0.0612 - 6s/epoch - 192ms/step
# Epoch 2/150
# 33/33 - 0s - loss: 0.0553 - val_loss: 0.0500 - 248ms/epoch - 8ms/step
# Epoch 3/150
# 33/33 - 0s - loss: 0.0501 - val_loss: 0.0456 - 238ms/epoch - 7ms/step
# Epoch 4/150
# 33/33 - 0s - loss: 0.0473 - val_loss: 0.0442 - 245ms/epoch - 7ms/step
# Epoch 5/150
# 33/33 - 0s - loss: 0.0447 - val_loss: 0.0427 - 257ms/epoch - 8ms/step
# Epoch 6/150
# 33/33 - 0s - loss: 0.0422 - val_loss: 0.0414 - 259ms/epoch - 8ms/step
# Epoch 7/150
# 33/33 - 0s - loss: 0.0400 - val_loss: 0.0402 - 331ms/epoch - 10ms/step
# Epoch 8/150
# 33/33 - 0s - loss: 0.0385 - val_loss: 0.0392 - 244ms/epoch - 7ms/step
# Epoch 9/150
# 33/33 - 0s - loss: 0.0375 - val_loss: 0.0384 - 257ms/epoch - 8ms/step
# Epoch 10/150
# 33/33 - 0s - loss: 0.0368 - val_loss: 0.0377 - 259ms/epoch - 8ms/step
# Epoch 11/150
# 33/33 - 0s - loss: 0.0363 - val_loss: 0.0370 - 254ms/epoch - 8ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.429
# Test NOx_ca RMSE: 25.846
# Test CO_ca RMSE: 0.204
# Test Chuva_ca RMSE: 0.740
# Test Pres_ca RMSE: 3.389
# Test Vel_Vento_ca RMSE: 0.520
# Test SO2_ca RMSE: 5.113
# Test PM10_ca RMSE: 15.007
# Test O3_ca RMSE: 17.221
# Test UR_ca RMSE: 11.320
# Test NO_ca RMSE: 15.161
# Test NO2_ca RMSE: 15.198

# %%
 mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.707
# Test NOx_ca MAE: 20.865
# Test CO_ca MAE: 0.157
# Test Chuva_ca MAE: 0.553
# Test Pres_ca MAE: 2.752
# Test Vel_Vento_ca MAE: 0.423
# Test SO2_ca MAE: 4.084
# Test PM10_ca MAE: 12.130
# Test O3_ca MAE: 13.766
# Test UR_ca MAE: 7.256
# Test NO_ca MAE: 12.054
# Test NO2_ca MAE: 12.176

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.050
# Test NOx_ca R2: 0.121
# Test CO_ca R2: -1.998
# Test Chuva_ca R2: -4.965
# Test Pres_ca R2: 0.208
# Test Vel_Vento_ca R2: -3.717
# Test SO2_ca R2: -2.294
# Test PM10_ca R2: -0.808
# Test O3_ca R2: -1.043
# Test UR_ca R2: -4.275
# Test NO_ca R2: 0.525
# Test NO2_ca R2: 0.505

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 3/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2112]

# split into train and test sets
values = reframed.values
n_train_days = 1584

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 50/50 - 7s - loss: 0.1456 - val_loss: 0.0472 - 7s/epoch - 146ms/step
# Epoch 2/150
# 50/50 - 0s - loss: 0.0536 - val_loss: 0.0454 - 418ms/epoch - 8ms/step
# Epoch 3/150
# 50/50 - 1s - loss: 0.0499 - val_loss: 0.0438 - 501ms/epoch - 10ms/step
# Epoch 4/150
# 50/50 - 1s - loss: 0.0470 - val_loss: 0.0424 - 503ms/epoch - 10ms/step
# Epoch 5/150
# 50/50 - 1s - loss: 0.0437 - val_loss: 0.0410 - 513ms/epoch - 10ms/step
# Epoch 6/150
# 50/50 - 0s - loss: 0.0405 - val_loss: 0.0399 - 400ms/epoch - 8ms/step
# Epoch 7/150
# 50/50 - 0s - loss: 0.0384 - val_loss: 0.0392 - 423ms/epoch - 8ms/step
# Epoch 8/150
# 50/50 - 0s - loss: 0.0372 - val_loss: 0.0387 - 425ms/epoch - 9ms/step
# Epoch 9/150
# 50/50 - 0s - loss: 0.0362 - val_loss: 0.0384 - 384ms/epoch - 8ms/step
# Epoch 10/150
# 50/50 - 0s - loss: 0.0354 - val_loss: 0.0381 - 426ms/epoch - 9ms/step
# Epoch 11/150
# 50/50 - 0s - loss: 0.0346 - val_loss: 0.0380 - 409ms/epoch - 8ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.098
# Test NOx_ca RMSE: 31.609
# Test CO_ca RMSE: 0.217
# Test Chuva_ca RMSE: 0.786
# Test Pres_ca RMSE: 2.912
# Test Vel_Vento_ca RMSE: 0.550
# Test SO2_ca RMSE: 5.552
# Test PM10_ca RMSE: 13.888
# Test O3_ca RMSE: 15.557
# Test UR_ca RMSE: 6.959
# Test NO_ca RMSE: 19.812
# Test NO2_ca RMSE: 19.352

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.408
# Test NOx_ca MAE: 25.045
# Test CO_ca MAE: 0.173
# Test Chuva_ca MAE: 0.556
# Test Pres_ca MAE: 2.287
# Test Vel_Vento_ca MAE: 0.451
# Test SO2_ca MAE: 4.512
# Test PM10_ca MAE: 11.026
# Test O3_ca MAE: 12.212
# Test UR_ca MAE: 5.692
# Test NO_ca MAE: 15.855
# Test NO2_ca MAE: 14.771

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: 0.154
# Test NOx_ca R2: -0.403
# Test CO_ca R2: -2.391
# Test Chuva_ca R2: -3.822
# Test Pres_ca R2: 0.488
# Test Vel_Vento_ca R2: -5.578
# Test SO2_ca R2: -2.304
# Test PM10_ca R2: -0.864
# Test O3_ca R2: -1.428
# Test UR_ca R2: -1.589
# Test NO_ca R2: -0.065
# Test NO2_ca R2: -0.027

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 4/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2640]

# split into train and test sets
values = reframed.values
n_train_days = 2112

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 66/66 - 6s - loss: 0.1208 - val_loss: 0.0524 - 6s/epoch - 90ms/step
# Epoch 2/150
# 66/66 - 0s - loss: 0.0480 - val_loss: 0.0513 - 429ms/epoch - 6ms/step
# Epoch 3/150
# 66/66 - 0s - loss: 0.0459 - val_loss: 0.0486 - 396ms/epoch - 6ms/step
# Epoch 4/150
# 66/66 - 0s - loss: 0.0434 - val_loss: 0.0453 - 404ms/epoch - 6ms/step
# Epoch 5/150
# 66/66 - 0s - loss: 0.0407 - val_loss: 0.0421 - 393ms/epoch - 6ms/step
# Epoch 6/150
# 66/66 - 0s - loss: 0.0382 - val_loss: 0.0403 - 468ms/epoch - 7ms/step
# Epoch 7/150
# 66/66 - 0s - loss: 0.0366 - val_loss: 0.0394 - 438ms/epoch - 7ms/step
# Epoch 8/150
# 66/66 - 0s - loss: 0.0356 - val_loss: 0.0387 - 406ms/epoch - 6ms/step
# Epoch 9/150
# 66/66 - 0s - loss: 0.0350 - val_loss: 0.0383 - 409ms/epoch - 6ms/step
# Epoch 10/150
# 66/66 - 0s - loss: 0.0344 - val_loss: 0.0379 - 394ms/epoch - 6ms/step
# Epoch 11/150
# 66/66 - 0s - loss: 0.0339 - val_loss: 0.0376 - 496ms/epoch - 8ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.394
# Test NOx_ca RMSE: 27.110
# Test CO_ca RMSE: 0.215
# Test Chuva_ca RMSE: 0.857
# Test Pres_ca RMSE: 2.150
# Test Vel_Vento_ca RMSE: 0.466
# Test SO2_ca RMSE: 5.623
# Test PM10_ca RMSE: 13.968
# Test O3_ca RMSE: 15.218
# Test UR_ca RMSE: 9.404
# Test NO_ca RMSE: 20.425
# Test NO2_ca RMSE: 15.233

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.619
# Test NOx_ca MAE: 21.820
# Test CO_ca MAE: 0.178
# Test Chuva_ca MAE: 0.547
# Test Pres_ca MAE: 1.675
# Test Vel_Vento_ca MAE: 0.375
# Test SO2_ca MAE: 4.706
# Test PM10_ca MAE: 11.220
# Test O3_ca MAE: 12.536
# Test UR_ca MAE: 6.546
# Test NO_ca MAE: 16.349
# Test NO2_ca MAE: 11.431

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.406
# Test NOx_ca R2: -0.015
# Test CO_ca R2: -1.877
# Test Chuva_ca R2: -4.927
# Test Pres_ca R2: 0.611
# Test Vel_Vento_ca R2: -3.550
# Test SO2_ca R2: -2.903
# Test PM10_ca R2: -1.073
# Test O3_ca R2: -1.263
# Test UR_ca R2: -2.885
# Test NO_ca R2: -0.614
# Test NO2_ca R2: 0.355

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 5/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:3168]

# split into train and test sets
values = reframed.values
n_train_days = 2640

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 83/83 - 8s - loss: 0.1203 - val_loss: 0.0509 - 8s/epoch - 93ms/step
# Epoch 2/150
# 83/83 - 1s - loss: 0.0488 - val_loss: 0.0474 - 608ms/epoch - 7ms/step
# Epoch 3/150
# 83/83 - 1s - loss: 0.0462 - val_loss: 0.0453 - 589ms/epoch - 7ms/step
# Epoch 4/150
# 83/83 - 1s - loss: 0.0436 - val_loss: 0.0429 - 630ms/epoch - 8ms/step
# Epoch 5/150
# 83/83 - 1s - loss: 0.0409 - val_loss: 0.0406 - 710ms/epoch - 9ms/step
# Epoch 6/150
# 83/83 - 1s - loss: 0.0388 - val_loss: 0.0391 - 639ms/epoch - 8ms/step
# Epoch 7/150
# 83/83 - 1s - loss: 0.0374 - val_loss: 0.0382 - 638ms/epoch - 8ms/step
# Epoch 8/150
# 83/83 - 1s - loss: 0.0363 - val_loss: 0.0375 - 588ms/epoch - 7ms/step
# Epoch 9/150
# 83/83 - 1s - loss: 0.0353 - val_loss: 0.0369 - 729ms/epoch - 9ms/step
# Epoch 10/150
# 83/83 - 1s - loss: 0.0345 - val_loss: 0.0362 - 718ms/epoch - 9ms/step
# Epoch 11/150
# 83/83 - 1s - loss: 0.0338 - val_loss: 0.0357 - 612ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.859
# Test NOx_ca RMSE: 13.944
# Test CO_ca RMSE: 0.235
# Test Chuva_ca RMSE: 0.803
# Test Pres_ca RMSE: 3.067
# Test Vel_Vento_ca RMSE: 0.549
# Test SO2_ca RMSE: 5.183
# Test PM10_ca RMSE: 14.683
# Test O3_ca RMSE: 15.923
# Test UR_ca RMSE: 6.654
# Test NO_ca RMSE: 8.854
# Test NO2_ca RMSE: 7.885

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 3.010
# Test NOx_ca MAE: 11.323
# Test CO_ca MAE: 0.191
# Test Chuva_ca MAE: 0.567
# Test Pres_ca MAE: 2.413
# Test Vel_Vento_ca MAE: 0.450
# Test SO2_ca MAE: 4.302
# Test PM10_ca MAE: 11.987
# Test O3_ca MAE: 12.708
# Test UR_ca MAE: 5.058
# Test NO_ca MAE: 7.003
# Test NO2_ca MAE: 6.073

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.715
# Test NOx_ca R2: 0.822
# Test CO_ca R2: -0.547
# Test Chuva_ca R2: -3.344
# Test Pres_ca R2: 0.377
# Test Vel_Vento_ca R2: -4.181
# Test SO2_ca R2: -2.551
# Test PM10_ca R2: -0.393
# Test O3_ca R2: -0.426
# Test UR_ca R2: -0.847
# Test NO_ca R2: 0.850
# Test NO2_ca R2: 0.850

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# **resultados finais**

# %%
RMSE_GRU_Temp_ca=statistics.mean(lista_Temp_ca_RMSE)
RMSE_GRU_NOx_ca=statistics.mean(lista_NOx_ca_RMSE)
RMSE_GRU_CO_ca=statistics.mean(lista_CO_ca_RMSE)
RMSE_GRU_Chuva_ca=statistics.mean(lista_Chuva_ca_RMSE)
RMSE_GRU_Pres_ca=statistics.mean(lista_Pres_ca_RMSE)
RMSE_GRU_Vel_Vento_ca=statistics.mean(lista_Vel_Vento_ca_RMSE)
RMSE_GRU_SO2_ca=statistics.mean(lista_SO2_ca_RMSE)
RMSE_GRU_PM10_ca=statistics.mean(lista_PM10_ca_RMSE)
RMSE_GRU_O3_ca=statistics.mean(lista_O3_ca_RMSE)
RMSE_GRU_UR_ca=statistics.mean(lista_UR_ca_RMSE)
RMSE_GRU_NO_ca=statistics.mean(lista_NO_ca_RMSE)
RMSE_GRU_NO2_ca=statistics.mean(lista_NO2_ca_RMSE)

# %% [markdown]
# ## Recurrent Neural Network

# %% [markdown]
# **listas para salvar rmse**

# %%
lista_Temp_ca_RMSE=[]
lista_NOx_ca_RMSE=[]
lista_CO_ca_RMSE=[]
lista_Chuva_ca_RMSE=[]
lista_Pres_ca_RMSE=[]
lista_Vel_Vento_ca_RMSE=[]
lista_SO2_ca_RMSE=[]
lista_PM10_ca_RMSE=[]
lista_O3_ca_RMSE=[]
lista_UR_ca_RMSE=[]
lista_NO_ca_RMSE=[]
lista_NO2_ca_RMSE=[]

# %% [markdown]
# #### treinamento do modelo para primeiro 1/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1056]

# split into train and test sets
values = reframed.values
n_train_days = 528

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 17/17 - 3s - loss: 0.2051 - val_loss: 0.1482 - 3s/epoch - 199ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.0766 - val_loss: 0.0821 - 276ms/epoch - 16ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0538 - val_loss: 0.0788 - 229ms/epoch - 13ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0499 - val_loss: 0.0704 - 311ms/epoch - 18ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0468 - val_loss: 0.0660 - 293ms/epoch - 17ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0448 - val_loss: 0.0634 - 297ms/epoch - 17ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0434 - val_loss: 0.0601 - 230ms/epoch - 14ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0420 - val_loss: 0.0577 - 272ms/epoch - 16ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0409 - val_loss: 0.0554 - 247ms/epoch - 15ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0399 - val_loss: 0.0534 - 270ms/epoch - 16ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0390 - val_loss: 0.0515 - 230ms/epoch - 14ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.548
# Test NOx_ca RMSE: 29.764
# Test CO_ca RMSE: 0.277
# Test Chuva_ca RMSE: 0.839
# Test Pres_ca RMSE: 2.890
# Test Vel_Vento_ca RMSE: 0.446
# Test SO2_ca RMSE: 6.422
# Test PM10_ca RMSE: 15.758
# Test O3_ca RMSE: 15.648
# Test UR_ca RMSE: 7.267
# Test NO_ca RMSE: 22.331
# Test NO2_ca RMSE: 22.727

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.872
# Test NOx_ca MAE: 23.972
# Test CO_ca MAE: 0.233
# Test Chuva_ca MAE: 0.548
# Test Pres_ca MAE: 2.344
# Test Vel_Vento_ca MAE: 0.359
# Test SO2_ca MAE: 5.224
# Test PM10_ca MAE: 12.904
# Test O3_ca MAE: 12.756
# Test UR_ca MAE: 5.990
# Test NO_ca MAE: 18.220
# Test NO2_ca MAE: 18.628

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.193
# Test NOx_ca R2: -0.279
# Test CO_ca R2: -3.592
# Test Chuva_ca R2: -3.863
# Test Pres_ca R2: 0.374
# Test Vel_Vento_ca R2: -2.823
# Test SO2_ca R2: -2.789
# Test PM10_ca R2: -1.215
# Test O3_ca R2: -1.247
# Test UR_ca R2: -1.865
# Test NO_ca R2: -0.830
# Test NO2_ca R2: -0.921

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 2/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1584]

# split into train and test sets
values = reframed.values
n_train_days = 1056

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 33/33 - 3s - loss: 0.1947 - val_loss: 0.0615 - 3s/epoch - 95ms/step
# Epoch 2/150
# 33/33 - 0s - loss: 0.0678 - val_loss: 0.0537 - 327ms/epoch - 10ms/step
# Epoch 3/150
# 33/33 - 0s - loss: 0.0572 - val_loss: 0.0498 - 275ms/epoch - 8ms/step
# Epoch 4/150
# 33/33 - 0s - loss: 0.0528 - val_loss: 0.0467 - 409ms/epoch - 12ms/step
# Epoch 5/150
# 33/33 - 0s - loss: 0.0493 - val_loss: 0.0444 - 315ms/epoch - 10ms/step
# Epoch 6/150
# 33/33 - 0s - loss: 0.0464 - val_loss: 0.0424 - 284ms/epoch - 9ms/step
# Epoch 7/150
# 33/33 - 0s - loss: 0.0439 - val_loss: 0.0408 - 272ms/epoch - 8ms/step
# Epoch 8/150
# 33/33 - 0s - loss: 0.0418 - val_loss: 0.0396 - 313ms/epoch - 9ms/step
# Epoch 9/150
# 33/33 - 0s - loss: 0.0402 - val_loss: 0.0389 - 259ms/epoch - 8ms/step
# Epoch 10/150
# 33/33 - 0s - loss: 0.0389 - val_loss: 0.0383 - 278ms/epoch - 8ms/step
# Epoch 11/150
# 33/33 - 0s - loss: 0.0379 - val_loss: 0.0378 - 279ms/epoch - 8ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.396
# Test NOx_ca RMSE: 26.201
# Test CO_ca RMSE: 0.221
# Test Chuva_ca RMSE: 0.746
# Test Pres_ca RMSE: 2.935
# Test Vel_Vento_ca RMSE: 0.518
# Test SO2_ca RMSE: 5.066
# Test PM10_ca RMSE: 15.272
# Test O3_ca RMSE: 15.877
# Test UR_ca RMSE: 11.232
# Test NO_ca RMSE: 15.180
# Test NO2_ca RMSE: 15.280

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.582
# Test NOx_ca MAE: 20.683
# Test CO_ca MAE: 0.171
# Test Chuva_ca MAE: 0.530
# Test Pres_ca MAE: 2.263
# Test Vel_Vento_ca MAE: 0.423
# Test SO2_ca MAE: 4.050
# Test PM10_ca MAE: 12.201
# Test O3_ca MAE: 12.898
# Test UR_ca MAE: 7.536
# Test NO_ca MAE: 12.033
# Test NO2_ca MAE: 12.143

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: 0.177
# Test NOx_ca R2: 0.250
# Test CO_ca R2: -1.600
# Test Chuva_ca R2: -5.203
# Test Pres_ca R2: 0.430
# Test Vel_Vento_ca R2: -3.248
# Test SO2_ca R2: -1.680
# Test PM10_ca R2: -0.827
# Test O3_ca R2: -0.513
# Test UR_ca R2: -5.526
# Test NO_ca R2: 0.467
# Test NO2_ca R2: 0.500

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 3/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2112]

# split into train and test sets
values = reframed.values
n_train_days = 1584

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 50/50 - 4s - loss: 0.1191 - val_loss: 0.0546 - 4s/epoch - 72ms/step
# Epoch 2/150
# 50/50 - 0s - loss: 0.0589 - val_loss: 0.0494 - 481ms/epoch - 10ms/step
# Epoch 3/150
# 50/50 - 1s - loss: 0.0516 - val_loss: 0.0487 - 568ms/epoch - 11ms/step
# Epoch 4/150
# 50/50 - 1s - loss: 0.0473 - val_loss: 0.0486 - 704ms/epoch - 14ms/step
# Epoch 5/150
# 50/50 - 1s - loss: 0.0441 - val_loss: 0.0492 - 639ms/epoch - 13ms/step
# Epoch 6/150
# 50/50 - 1s - loss: 0.0420 - val_loss: 0.0485 - 641ms/epoch - 13ms/step
# Epoch 7/150
# 50/50 - 1s - loss: 0.0400 - val_loss: 0.0441 - 604ms/epoch - 12ms/step
# Epoch 8/150
# 50/50 - 1s - loss: 0.0376 - val_loss: 0.0398 - 588ms/epoch - 12ms/step
# Epoch 9/150
# 50/50 - 1s - loss: 0.0357 - val_loss: 0.0380 - 605ms/epoch - 12ms/step
# Epoch 10/150
# 50/50 - 1s - loss: 0.0347 - val_loss: 0.0375 - 583ms/epoch - 12ms/step
# Epoch 11/150
# 50/50 - 1s - loss: 0.0341 - val_loss: 0.0374 - 630ms/epoch - 13ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.132
# Test NOx_ca RMSE: 29.094
# Test CO_ca RMSE: 0.200
# Test Chuva_ca RMSE: 0.785
# Test Pres_ca RMSE: 4.045
# Test Vel_Vento_ca RMSE: 0.550
# Test SO2_ca RMSE: 5.384
# Test PM10_ca RMSE: 13.660
# Test O3_ca RMSE: 15.793
# Test UR_ca RMSE: 7.641
# Test NO_ca RMSE: 20.662
# Test NO2_ca RMSE: 17.747

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.449
# Test NOx_ca MAE: 23.088
# Test CO_ca MAE: 0.163
# Test Chuva_ca MAE: 0.564
# Test Pres_ca MAE: 3.281
# Test Vel_Vento_ca MAE: 0.454
# Test SO2_ca MAE: 4.490
# Test PM10_ca MAE: 10.960
# Test O3_ca MAE: 12.437
# Test UR_ca MAE: 6.288
# Test NO_ca MAE: 16.068
# Test NO2_ca MAE: 13.349

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: 0.038
# Test NOx_ca R2: -0.242
# Test CO_ca R2: -1.823
# Test Chuva_ca R2: -4.518
# Test Pres_ca R2: -0.203
# Test Vel_Vento_ca R2: -4.750
# Test SO2_ca R2: -2.036
# Test PM10_ca R2: -0.447
# Test O3_ca R2: -1.536
# Test UR_ca R2: -1.401
# Test NO_ca R2: -0.157
# Test NO2_ca R2: 0.101

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 4/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2640]

# split into train and test sets
values = reframed.values
n_train_days = 2112

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 66/66 - 2s - loss: 0.1184 - val_loss: 0.0568 - 2s/epoch - 33ms/step
# Epoch 2/150
# 66/66 - 0s - loss: 0.0501 - val_loss: 0.0509 - 368ms/epoch - 6ms/step
# Epoch 3/150
# 66/66 - 0s - loss: 0.0449 - val_loss: 0.0483 - 353ms/epoch - 5ms/step
# Epoch 4/150
# 66/66 - 0s - loss: 0.0420 - val_loss: 0.0467 - 342ms/epoch - 5ms/step
# Epoch 5/150
# 66/66 - 0s - loss: 0.0401 - val_loss: 0.0456 - 370ms/epoch - 6ms/step
# Epoch 6/150
# 66/66 - 0s - loss: 0.0387 - val_loss: 0.0447 - 349ms/epoch - 5ms/step
# Epoch 7/150
# 66/66 - 0s - loss: 0.0376 - val_loss: 0.0439 - 350ms/epoch - 5ms/step
# Epoch 8/150
# 66/66 - 0s - loss: 0.0367 - val_loss: 0.0433 - 360ms/epoch - 5ms/step
# Epoch 9/150
# 66/66 - 0s - loss: 0.0359 - val_loss: 0.0427 - 366ms/epoch - 6ms/step
# Epoch 10/150
# 66/66 - 0s - loss: 0.0353 - val_loss: 0.0421 - 365ms/epoch - 6ms/step
# Epoch 11/150
# 66/66 - 0s - loss: 0.0347 - val_loss: 0.0416 - 359ms/epoch - 5ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.468
# Test NOx_ca RMSE: 26.734
# Test CO_ca RMSE: 0.218
# Test Chuva_ca RMSE: 0.875
# Test Pres_ca RMSE: 2.301
# Test Vel_Vento_ca RMSE: 0.473
# Test SO2_ca RMSE: 5.558
# Test PM10_ca RMSE: 14.334
# Test O3_ca RMSE: 15.093
# Test UR_ca RMSE: 10.194
# Test NO_ca RMSE: 19.927
# Test NO2_ca RMSE: 15.234

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.709
# Test NOx_ca MAE: 21.002
# Test CO_ca MAE: 0.181
# Test Chuva_ca MAE: 0.547
# Test Pres_ca MAE: 1.774
# Test Vel_Vento_ca MAE: 0.385
# Test SO2_ca MAE: 4.670
# Test PM10_ca MAE: 11.726
# Test O3_ca MAE: 12.518
# Test UR_ca MAE: 7.519
# Test NO_ca MAE: 15.483
# Test NO2_ca MAE: 11.202

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.476
# Test NOx_ca R2: 0.040
# Test CO_ca R2: -1.869
# Test Chuva_ca R2: -5.197
# Test Pres_ca R2: 0.567
# Test Vel_Vento_ca R2: -4.595
# Test SO2_ca R2: -3.492
# Test PM10_ca R2: -1.283
# Test O3_ca R2: -1.644
# Test UR_ca R2: -2.440
# Test NO_ca R2: -0.354
# Test NO2_ca R2: 0.402

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# #### treinamento do modelo para primeiro 5/5 da divisão

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:3168]

# split into train and test sets
values = reframed.values
n_train_days = 2640

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))
# Out:
# Epoch 1/150
# 83/83 - 3s - loss: 0.0751 - val_loss: 0.0535 - 3s/epoch - 31ms/step
# Epoch 2/150
# 83/83 - 1s - loss: 0.0485 - val_loss: 0.0477 - 578ms/epoch - 7ms/step
# Epoch 3/150
# 83/83 - 1s - loss: 0.0435 - val_loss: 0.0446 - 594ms/epoch - 7ms/step
# Epoch 4/150
# 83/83 - 1s - loss: 0.0403 - val_loss: 0.0426 - 574ms/epoch - 7ms/step
# Epoch 5/150
# 83/83 - 1s - loss: 0.0383 - val_loss: 0.0413 - 560ms/epoch - 7ms/step
# Epoch 6/150
# 83/83 - 1s - loss: 0.0369 - val_loss: 0.0406 - 563ms/epoch - 7ms/step
# Epoch 7/150
# 83/83 - 1s - loss: 0.0359 - val_loss: 0.0401 - 553ms/epoch - 7ms/step
# Epoch 8/150
# 83/83 - 1s - loss: 0.0352 - val_loss: 0.0396 - 567ms/epoch - 7ms/step
# Epoch 9/150
# 83/83 - 1s - loss: 0.0346 - val_loss: 0.0391 - 565ms/epoch - 7ms/step
# Epoch 10/150
# 83/83 - 1s - loss: 0.0340 - val_loss: 0.0387 - 571ms/epoch - 7ms/step
# Epoch 11/150
# 83/83 - 1s - loss: 0.0336 - val_loss: 0.0382 - 563ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %% [markdown]
# **resultados do treinamento**

# %%
yhat = model.predict(test_X)

yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))

inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat=pd.DataFrame(inv_yhat,columns=names)
df_test_y=pd.DataFrame(inv_test_y,columns=names)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.946
# Test NOx_ca RMSE: 11.883
# Test CO_ca RMSE: 0.236
# Test Chuva_ca RMSE: 0.793
# Test Pres_ca RMSE: 2.544
# Test Vel_Vento_ca RMSE: 0.595
# Test SO2_ca RMSE: 5.098
# Test PM10_ca RMSE: 14.477
# Test O3_ca RMSE: 17.524
# Test UR_ca RMSE: 6.810
# Test NO_ca RMSE: 9.116
# Test NO2_ca RMSE: 6.876

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 3.061
# Test NOx_ca MAE: 9.350
# Test CO_ca MAE: 0.191
# Test Chuva_ca MAE: 0.556
# Test Pres_ca MAE: 1.883
# Test Vel_Vento_ca MAE: 0.491
# Test SO2_ca MAE: 4.252
# Test PM10_ca MAE: 11.587
# Test O3_ca MAE: 14.118
# Test UR_ca MAE: 5.011
# Test NO_ca MAE: 7.065
# Test NO2_ca MAE: 5.224

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.710
# Test NOx_ca R2: 0.883
# Test CO_ca R2: -0.757
# Test Chuva_ca R2: -5.006
# Test Pres_ca R2: 0.562
# Test Vel_Vento_ca R2: -6.840
# Test SO2_ca R2: -2.841
# Test PM10_ca R2: -0.138
# Test O3_ca R2: -1.069
# Test UR_ca R2: -0.477
# Test NO_ca R2: 0.827
# Test NO2_ca R2: 0.880

# %% [markdown]
# **histórico do treinamento**

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
pyplot.plot(history.history['loss'], label='train', color='blue')
pyplot.plot(history.history['val_loss'], label='test', color='red')
plt.xlabel('epoch',fontsize=20)
plt.ylabel('loss',fontsize=20) 
# plt.title('train and test loss evolution',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
pyplot.legend(fontsize=20)
pyplot.show()

# %% [markdown]
# **resultados finais**

# %%
RMSE_RNN_Temp_ca=statistics.mean(lista_Temp_ca_RMSE)
RMSE_RNN_NOx_ca=statistics.mean(lista_NOx_ca_RMSE)
RMSE_RNN_CO_ca=statistics.mean(lista_CO_ca_RMSE)
RMSE_RNN_Chuva_ca=statistics.mean(lista_Chuva_ca_RMSE)
RMSE_RNN_Pres_ca=statistics.mean(lista_Pres_ca_RMSE)
RMSE_RNN_Vel_Vento_ca=statistics.mean(lista_Vel_Vento_ca_RMSE)
RMSE_RNN_SO2_ca=statistics.mean(lista_SO2_ca_RMSE)
RMSE_RNN_PM10_ca=statistics.mean(lista_PM10_ca_RMSE)
RMSE_RNN_O3_ca=statistics.mean(lista_O3_ca_RMSE)
RMSE_RNN_UR_ca=statistics.mean(lista_UR_ca_RMSE)
RMSE_RNN_NO_ca=statistics.mean(lista_NO_ca_RMSE)
RMSE_RNN_NO2_ca=statistics.mean(lista_NO2_ca_RMSE)

# %% [markdown]
# ## Ensemble de redes (teste)

# %% [markdown]
# ### validação cruzada (1/5)

# %% [markdown]
# **pré-processamento**

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1056]

# split into train and test sets
values = reframed.values
n_train_days = 528

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# %% [markdown]
# **treinamento LSTM**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat_lstm=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
df_test_y=pd.DataFrame(inv_test_y,columns=names)
# Out:
# Epoch 1/150
# 17/17 - 5s - loss: 0.3005 - val_loss: 0.2923 - 5s/epoch - 297ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.1793 - val_loss: 0.1253 - 147ms/epoch - 9ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0605 - val_loss: 0.0748 - 166ms/epoch - 10ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0438 - val_loss: 0.0656 - 157ms/epoch - 9ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0426 - val_loss: 0.0674 - 156ms/epoch - 9ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0420 - val_loss: 0.0664 - 165ms/epoch - 10ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0418 - val_loss: 0.0660 - 177ms/epoch - 10ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0417 - val_loss: 0.0659 - 175ms/epoch - 10ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0415 - val_loss: 0.0655 - 165ms/epoch - 10ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0414 - val_loss: 0.0652 - 170ms/epoch - 10ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0413 - val_loss: 0.0648 - 173ms/epoch - 10ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_lstm.rename(columns={
    'Temp_ca':'Temp_ca_lstm', 
    'NOx_ca':'NOx_ca_lstm', 
    'CO_ca':'CO_ca_lstm', 
    'Chuva_ca':'Chuva_ca_lstm', 
    'Pres_ca':'Pres_ca_lstm',
    'Vel_Vento_ca':'Vel_Vento_ca_lstm',
    'SO2_ca':'SO2_ca_lstm', 
    'PM10_ca':'PM10_ca_lstm', 
    'O3_ca':'O3_ca_lstm', 
    'UR_ca':'UR_ca_lstm', 
    'NO_ca':'NO_ca_lstm', 
    'NO2_ca':'NO2_ca_lstm'
}, inplace=True)

# %% [markdown]
# **GRU**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_gru=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 17/17 - 5s - loss: 0.2640 - val_loss: 0.1895 - 5s/epoch - 281ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.1023 - val_loss: 0.0690 - 176ms/epoch - 10ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0480 - val_loss: 0.0719 - 147ms/epoch - 9ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0432 - val_loss: 0.0720 - 155ms/epoch - 9ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0421 - val_loss: 0.0673 - 174ms/epoch - 10ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0415 - val_loss: 0.0678 - 145ms/epoch - 9ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0413 - val_loss: 0.0677 - 142ms/epoch - 8ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0411 - val_loss: 0.0672 - 148ms/epoch - 9ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0408 - val_loss: 0.0668 - 170ms/epoch - 10ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0405 - val_loss: 0.0663 - 175ms/epoch - 10ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0402 - val_loss: 0.0657 - 178ms/epoch - 10ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_gru.rename(columns={
    'Temp_ca':'Temp_ca_gru', 
    'NOx_ca':'NOx_ca_gru', 
    'CO_ca':'CO_ca_gru', 
    'Chuva_ca':'Chuva_ca_gru', 
    'Pres_ca':'Pres_ca_gru',
    'Vel_Vento_ca':'Vel_Vento_ca_gru',
    'SO2_ca':'SO2_ca_gru', 
    'PM10_ca':'PM10_ca_gru', 
    'O3_ca':'O3_ca_gru', 
    'UR_ca':'UR_ca_gru', 
    'NO_ca':'NO_ca_gru', 
    'NO2_ca':'NO2_ca_gru'
}, inplace=True)

# %% [markdown]
# **RNN**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_rnn=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 17/17 - 3s - loss: 0.2383 - val_loss: 0.1255 - 3s/epoch - 155ms/step
# Epoch 2/150
# 17/17 - 0s - loss: 0.0658 - val_loss: 0.0773 - 172ms/epoch - 10ms/step
# Epoch 3/150
# 17/17 - 0s - loss: 0.0527 - val_loss: 0.0694 - 190ms/epoch - 11ms/step
# Epoch 4/150
# 17/17 - 0s - loss: 0.0490 - val_loss: 0.0648 - 188ms/epoch - 11ms/step
# Epoch 5/150
# 17/17 - 0s - loss: 0.0466 - val_loss: 0.0642 - 182ms/epoch - 11ms/step
# Epoch 6/150
# 17/17 - 0s - loss: 0.0451 - val_loss: 0.0615 - 206ms/epoch - 12ms/step
# Epoch 7/150
# 17/17 - 0s - loss: 0.0439 - val_loss: 0.0601 - 198ms/epoch - 12ms/step
# Epoch 8/150
# 17/17 - 0s - loss: 0.0428 - val_loss: 0.0588 - 167ms/epoch - 10ms/step
# Epoch 9/150
# 17/17 - 0s - loss: 0.0418 - val_loss: 0.0576 - 189ms/epoch - 11ms/step
# Epoch 10/150
# 17/17 - 0s - loss: 0.0410 - val_loss: 0.0567 - 169ms/epoch - 10ms/step
# Epoch 11/150
# 17/17 - 0s - loss: 0.0402 - val_loss: 0.0558 - 187ms/epoch - 11ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_rnn.rename(columns={
    'Temp_ca':'Temp_ca_rnn', 
    'NOx_ca':'NOx_ca_rnn', 
    'CO_ca':'CO_ca_rnn', 
    'Chuva_ca':'Chuva_ca_rnn', 
    'Pres_ca':'Pres_ca_rnn',
    'Vel_Vento_ca':'Vel_Vento_ca_rnn',
    'SO2_ca':'SO2_ca_rnn', 
    'PM10_ca':'PM10_ca_rnn', 
    'O3_ca':'O3_ca_rnn', 
    'UR_ca':'UR_ca_rnn', 
    'NO_ca':'NO_ca_rnn', 
    'NO2_ca':'NO2_ca_rnn'
}, inplace=True)

# %% [markdown]
# **Montagem do ensemble**

# %%
df_concat = pd.concat([df_inv_yhat_lstm, df_inv_yhat_gru,df_inv_yhat_rnn], axis=1)

# %%
col_names =  ['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca','Vel_Vento_ca','SO2_ca', 
              'PM10_ca', 'O3_ca', 'UR_ca', 'NO_ca', 'NO2_ca']
df_inv_yhat  = pd.DataFrame(columns = col_names,index=[i for i in range(len(df_concat))])
#df_inv_yhat

# %%
#Temp_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_RNN_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    elif RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_GRU_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_lstm'][i]))/6    
    elif RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_lstm'][i]))/6

# %%
#NOx_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_RNN_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    elif RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_GRU_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_lstm'][i]))/6    
    elif RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_lstm'][i]))/6

# %%
#CO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_RNN_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_gru'][i]))/6    
    elif RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_GRU_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_lstm'][i]))/6    
    elif RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_lstm'][i]))/6

# %%
#Chuva_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    elif RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_GRU_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_lstm'][i]))/6    
    elif RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_lstm'][i]))/6

# %%
#Pres_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_RNN_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    elif RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_GRU_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_lstm'][i]))/6    
    elif RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_lstm'][i]))/6

# %%
#Vel_Vento_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    elif RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_GRU_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6    
    elif RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6

# %%
#SO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_RNN_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_GRU_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_lstm'][i]))/6

# %%
#PM10_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_RNN_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    elif RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_GRU_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_lstm'][i]))/6    
    elif RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    else:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_lstm'][i]))/6

# %%
#O3_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_RNN_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_gru'][i]))/6    
    elif RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_GRU_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_lstm'][i]))/6    
    elif RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_gru'][i]))/6    
    else:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_lstm'][i]))/6

# %%
#UR_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_RNN_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_gru'][i]))/6    
    elif RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_GRU_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_lstm'][i]))/6    
    elif RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_gru'][i]))/6    
    else:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_lstm'][i]))/6

# %%
#NO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_RNN_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_GRU_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_lstm'][i]))/6

# %%
#NO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_RNN_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_GRU_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_lstm'][i]))/6

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.554
# Test NOx_ca RMSE: 28.536
# Test CO_ca RMSE: 0.227
# Test Chuva_ca RMSE: 0.788
# Test Pres_ca RMSE: 2.790
# Test Vel_Vento_ca RMSE: 0.489
# Test SO2_ca RMSE: 5.839
# Test PM10_ca RMSE: 15.091
# Test O3_ca RMSE: 14.846
# Test UR_ca RMSE: 6.487
# Test NO_ca RMSE: 17.279
# Test NO2_ca RMSE: 17.143

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.886
# Test NOx_ca MAE: 22.170
# Test CO_ca MAE: 0.188
# Test Chuva_ca MAE: 0.503
# Test Pres_ca MAE: 2.250
# Test Vel_Vento_ca MAE: 0.398
# Test SO2_ca MAE: 4.774
# Test PM10_ca MAE: 12.326
# Test O3_ca MAE: 12.038
# Test UR_ca MAE: 5.272
# Test NO_ca MAE: 13.458
# Test NO2_ca MAE: 13.394

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.330
# Test NOx_ca R2: 0.109
# Test CO_ca R2: -2.425
# Test Chuva_ca R2: -3.628
# Test Pres_ca R2: 0.305
# Test Vel_Vento_ca R2: -4.586
# Test SO2_ca R2: -2.093
# Test PM10_ca R2: -1.010
# Test O3_ca R2: -1.198
# Test UR_ca R2: -1.664
# Test NO_ca R2: 0.061
# Test NO2_ca R2: 0.048

# %% [markdown]
# ### validação cruzada (2/5)

# %% [markdown]
# **pré-processamento**

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:1584]

# split into train and test sets
values = reframed.values
n_train_days = 1056

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# %% [markdown]
# **treinamento LSTM**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat_lstm=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
df_test_y=pd.DataFrame(inv_test_y,columns=names)
# Out:
# Epoch 1/150
# 33/33 - 4s - loss: 0.2884 - val_loss: 0.1697 - 4s/epoch - 126ms/step
# Epoch 2/150
# 33/33 - 0s - loss: 0.0740 - val_loss: 0.0497 - 225ms/epoch - 7ms/step
# Epoch 3/150
# 33/33 - 0s - loss: 0.0513 - val_loss: 0.0496 - 213ms/epoch - 6ms/step
# Epoch 4/150
# 33/33 - 0s - loss: 0.0501 - val_loss: 0.0495 - 219ms/epoch - 7ms/step
# Epoch 5/150
# 33/33 - 0s - loss: 0.0494 - val_loss: 0.0489 - 217ms/epoch - 7ms/step
# Epoch 6/150
# 33/33 - 0s - loss: 0.0488 - val_loss: 0.0483 - 220ms/epoch - 7ms/step
# Epoch 7/150
# 33/33 - 0s - loss: 0.0481 - val_loss: 0.0474 - 223ms/epoch - 7ms/step
# Epoch 8/150
# 33/33 - 0s - loss: 0.0472 - val_loss: 0.0463 - 213ms/epoch - 6ms/step
# Epoch 9/150
# 33/33 - 0s - loss: 0.0460 - val_loss: 0.0448 - 237ms/epoch - 7ms/step
# Epoch 10/150
# 33/33 - 0s - loss: 0.0443 - val_loss: 0.0434 - 221ms/epoch - 7ms/step
# Epoch 11/150
# 33/33 - 0s - loss: 0.0422 - val_loss: 0.0423 - 227ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_lstm.rename(columns={
    'Temp_ca':'Temp_ca_lstm', 
    'NOx_ca':'NOx_ca_lstm', 
    'CO_ca':'CO_ca_lstm', 
    'Chuva_ca':'Chuva_ca_lstm', 
    'Pres_ca':'Pres_ca_lstm',
    'Vel_Vento_ca':'Vel_Vento_ca_lstm',
    'SO2_ca':'SO2_ca_lstm', 
    'PM10_ca':'PM10_ca_lstm', 
    'O3_ca':'O3_ca_lstm', 
    'UR_ca':'UR_ca_lstm', 
    'NO_ca':'NO_ca_lstm', 
    'NO2_ca':'NO2_ca_lstm'
}, inplace=True)

# %% [markdown]
# **GRU**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_gru=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 33/33 - 4s - loss: 0.1938 - val_loss: 0.0740 - 4s/epoch - 129ms/step
# Epoch 2/150
# 33/33 - 0s - loss: 0.0533 - val_loss: 0.0504 - 218ms/epoch - 7ms/step
# Epoch 3/150
# 33/33 - 0s - loss: 0.0502 - val_loss: 0.0490 - 188ms/epoch - 6ms/step
# Epoch 4/150
# 33/33 - 0s - loss: 0.0482 - val_loss: 0.0477 - 207ms/epoch - 6ms/step
# Epoch 5/150
# 33/33 - 0s - loss: 0.0471 - val_loss: 0.0467 - 212ms/epoch - 6ms/step
# Epoch 6/150
# 33/33 - 0s - loss: 0.0457 - val_loss: 0.0455 - 198ms/epoch - 6ms/step
# Epoch 7/150
# 33/33 - 0s - loss: 0.0441 - val_loss: 0.0442 - 215ms/epoch - 7ms/step
# Epoch 8/150
# 33/33 - 0s - loss: 0.0422 - val_loss: 0.0429 - 195ms/epoch - 6ms/step
# Epoch 9/150
# 33/33 - 0s - loss: 0.0401 - val_loss: 0.0420 - 200ms/epoch - 6ms/step
# Epoch 10/150
# 33/33 - 0s - loss: 0.0382 - val_loss: 0.0415 - 216ms/epoch - 7ms/step
# Epoch 11/150
# 33/33 - 0s - loss: 0.0367 - val_loss: 0.0412 - 217ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_gru.rename(columns={
    'Temp_ca':'Temp_ca_gru', 
    'NOx_ca':'NOx_ca_gru', 
    'CO_ca':'CO_ca_gru', 
    'Chuva_ca':'Chuva_ca_gru', 
    'Pres_ca':'Pres_ca_gru',
    'Vel_Vento_ca':'Vel_Vento_ca_gru',
    'SO2_ca':'SO2_ca_gru', 
    'PM10_ca':'PM10_ca_gru', 
    'O3_ca':'O3_ca_gru', 
    'UR_ca':'UR_ca_gru', 
    'NO_ca':'NO_ca_gru', 
    'NO2_ca':'NO2_ca_gru'
}, inplace=True)

# %% [markdown]
# **RNN**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_rnn=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 33/33 - 2s - loss: 0.1288 - val_loss: 0.0603 - 2s/epoch - 60ms/step
# Epoch 2/150
# 33/33 - 0s - loss: 0.0698 - val_loss: 0.0537 - 207ms/epoch - 6ms/step
# Epoch 3/150
# 33/33 - 0s - loss: 0.0587 - val_loss: 0.0508 - 216ms/epoch - 7ms/step
# Epoch 4/150
# 33/33 - 0s - loss: 0.0521 - val_loss: 0.0489 - 235ms/epoch - 7ms/step
# Epoch 5/150
# 33/33 - 0s - loss: 0.0479 - val_loss: 0.0477 - 209ms/epoch - 6ms/step
# Epoch 6/150
# 33/33 - 0s - loss: 0.0450 - val_loss: 0.0468 - 215ms/epoch - 7ms/step
# Epoch 7/150
# 33/33 - 0s - loss: 0.0430 - val_loss: 0.0461 - 208ms/epoch - 6ms/step
# Epoch 8/150
# 33/33 - 0s - loss: 0.0416 - val_loss: 0.0455 - 217ms/epoch - 7ms/step
# Epoch 9/150
# 33/33 - 0s - loss: 0.0405 - val_loss: 0.0451 - 209ms/epoch - 6ms/step
# Epoch 10/150
# 33/33 - 0s - loss: 0.0397 - val_loss: 0.0448 - 205ms/epoch - 6ms/step
# Epoch 11/150
# 33/33 - 0s - loss: 0.0391 - val_loss: 0.0445 - 197ms/epoch - 6ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_rnn.rename(columns={
    'Temp_ca':'Temp_ca_rnn', 
    'NOx_ca':'NOx_ca_rnn', 
    'CO_ca':'CO_ca_rnn', 
    'Chuva_ca':'Chuva_ca_rnn', 
    'Pres_ca':'Pres_ca_rnn',
    'Vel_Vento_ca':'Vel_Vento_ca_rnn',
    'SO2_ca':'SO2_ca_rnn', 
    'PM10_ca':'PM10_ca_rnn', 
    'O3_ca':'O3_ca_rnn', 
    'UR_ca':'UR_ca_rnn', 
    'NO_ca':'NO_ca_rnn', 
    'NO2_ca':'NO2_ca_rnn'
}, inplace=True)

# %% [markdown]
# **Montagem do ensemble**

# %%
df_concat = pd.concat([df_inv_yhat_lstm, df_inv_yhat_gru,df_inv_yhat_rnn], axis=1)

# %%
col_names =  ['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca','Vel_Vento_ca','SO2_ca', 
              'PM10_ca', 'O3_ca', 'UR_ca', 'NO_ca', 'NO2_ca']
df_inv_yhat  = pd.DataFrame(columns = col_names,index=[i for i in range(len(df_concat))])
#df_inv_yhat

# %%
#Temp_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_RNN_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    elif RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_GRU_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_lstm'][i]))/6    
    elif RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_lstm'][i]))/6

# %%
#NOx_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_RNN_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    elif RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_GRU_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_lstm'][i]))/6    
    elif RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_lstm'][i]))/6

# %%
#CO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_RNN_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_gru'][i]))/6    
    elif RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_GRU_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_lstm'][i]))/6    
    elif RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_lstm'][i]))/6

# %%
#Chuva_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    elif RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_GRU_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_lstm'][i]))/6    
    elif RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_lstm'][i]))/6

# %%
#Pres_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_RNN_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    elif RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_GRU_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_lstm'][i]))/6    
    elif RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_lstm'][i]))/6

# %%
#Vel_Vento_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    elif RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_GRU_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6    
    elif RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6

# %%
#SO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_RNN_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_GRU_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_lstm'][i]))/6

# %%
#PM10_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_RNN_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    elif RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_GRU_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_lstm'][i]))/6    
    elif RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    else:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_lstm'][i]))/6

# %%
#O3_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_RNN_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_gru'][i]))/6    
    elif RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_GRU_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_lstm'][i]))/6    
    elif RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_gru'][i]))/6    
    else:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_lstm'][i]))/6

# %%
#UR_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_RNN_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_gru'][i]))/6    
    elif RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_GRU_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_lstm'][i]))/6    
    elif RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_gru'][i]))/6    
    else:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_lstm'][i]))/6

# %%
#NO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_RNN_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_GRU_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_lstm'][i]))/6

# %%
#NO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_RNN_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_GRU_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_lstm'][i]))/6

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.240
# Test NOx_ca RMSE: 25.824
# Test CO_ca RMSE: 0.201
# Test Chuva_ca RMSE: 0.750
# Test Pres_ca RMSE: 2.597
# Test Vel_Vento_ca RMSE: 0.496
# Test SO2_ca RMSE: 5.031
# Test PM10_ca RMSE: 14.860
# Test O3_ca RMSE: 16.610
# Test UR_ca RMSE: 12.080
# Test NO_ca RMSE: 15.553
# Test NO2_ca RMSE: 15.048

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.555
# Test NOx_ca MAE: 20.562
# Test CO_ca MAE: 0.157
# Test Chuva_ca MAE: 0.526
# Test Pres_ca MAE: 1.976
# Test Vel_Vento_ca MAE: 0.403
# Test SO2_ca MAE: 4.023
# Test PM10_ca MAE: 11.885
# Test O3_ca MAE: 13.406
# Test UR_ca MAE: 8.578
# Test NO_ca MAE: 12.529
# Test NO2_ca MAE: 12.093

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: 0.134
# Test NOx_ca R2: -0.012
# Test CO_ca R2: -2.821
# Test Chuva_ca R2: -5.102
# Test Pres_ca R2: 0.577
# Test Vel_Vento_ca R2: -2.702
# Test SO2_ca R2: -1.815
# Test PM10_ca R2: -0.672
# Test O3_ca R2: -0.940
# Test UR_ca R2: -6.392
# Test NO_ca R2: 0.390
# Test NO2_ca R2: 0.459

# %% [markdown]
# ### validação cruzada (3/5)

# %% [markdown]
# **pré-processamento**

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2112]

# split into train and test sets
values = reframed.values
n_train_days = 1584

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# %% [markdown]
# **treinamento LSTM**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat_lstm=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
df_test_y=pd.DataFrame(inv_test_y,columns=names)
# Out:
# Epoch 1/150
# 50/50 - 5s - loss: 0.2322 - val_loss: 0.0555 - 5s/epoch - 109ms/step
# Epoch 2/150
# 50/50 - 0s - loss: 0.0545 - val_loss: 0.0452 - 340ms/epoch - 7ms/step
# Epoch 3/150
# 50/50 - 0s - loss: 0.0508 - val_loss: 0.0445 - 340ms/epoch - 7ms/step
# Epoch 4/150
# 50/50 - 0s - loss: 0.0497 - val_loss: 0.0440 - 353ms/epoch - 7ms/step
# Epoch 5/150
# 50/50 - 0s - loss: 0.0484 - val_loss: 0.0433 - 337ms/epoch - 7ms/step
# Epoch 6/150
# 50/50 - 0s - loss: 0.0469 - val_loss: 0.0426 - 341ms/epoch - 7ms/step
# Epoch 7/150
# 50/50 - 0s - loss: 0.0450 - val_loss: 0.0418 - 360ms/epoch - 7ms/step
# Epoch 8/150
# 50/50 - 0s - loss: 0.0428 - val_loss: 0.0407 - 344ms/epoch - 7ms/step
# Epoch 9/150
# 50/50 - 0s - loss: 0.0402 - val_loss: 0.0395 - 354ms/epoch - 7ms/step
# Epoch 10/150
# 50/50 - 0s - loss: 0.0377 - val_loss: 0.0387 - 347ms/epoch - 7ms/step
# Epoch 11/150
# 50/50 - 0s - loss: 0.0360 - val_loss: 0.0383 - 338ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_lstm.rename(columns={
    'Temp_ca':'Temp_ca_lstm', 
    'NOx_ca':'NOx_ca_lstm', 
    'CO_ca':'CO_ca_lstm', 
    'Chuva_ca':'Chuva_ca_lstm', 
    'Pres_ca':'Pres_ca_lstm',
    'Vel_Vento_ca':'Vel_Vento_ca_lstm',
    'SO2_ca':'SO2_ca_lstm', 
    'PM10_ca':'PM10_ca_lstm', 
    'O3_ca':'O3_ca_lstm', 
    'UR_ca':'UR_ca_lstm', 
    'NO_ca':'NO_ca_lstm', 
    'NO2_ca':'NO2_ca_lstm'
}, inplace=True)

# %% [markdown]
# **GRU**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_gru=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 50/50 - 5s - loss: 0.1417 - val_loss: 0.0489 - 5s/epoch - 98ms/step
# Epoch 2/150
# 50/50 - 0s - loss: 0.0523 - val_loss: 0.0474 - 319ms/epoch - 6ms/step
# Epoch 3/150
# 50/50 - 0s - loss: 0.0490 - val_loss: 0.0470 - 325ms/epoch - 7ms/step
# Epoch 4/150
# 50/50 - 0s - loss: 0.0461 - val_loss: 0.0467 - 335ms/epoch - 7ms/step
# Epoch 5/150
# 50/50 - 0s - loss: 0.0425 - val_loss: 0.0463 - 302ms/epoch - 6ms/step
# Epoch 6/150
# 50/50 - 0s - loss: 0.0390 - val_loss: 0.0459 - 309ms/epoch - 6ms/step
# Epoch 7/150
# 50/50 - 0s - loss: 0.0369 - val_loss: 0.0459 - 311ms/epoch - 6ms/step
# Epoch 8/150
# 50/50 - 0s - loss: 0.0356 - val_loss: 0.0461 - 308ms/epoch - 6ms/step
# Epoch 9/150
# 50/50 - 0s - loss: 0.0345 - val_loss: 0.0464 - 320ms/epoch - 6ms/step
# Epoch 10/150
# 50/50 - 0s - loss: 0.0336 - val_loss: 0.0468 - 309ms/epoch - 6ms/step
# Epoch 11/150
# 50/50 - 0s - loss: 0.0330 - val_loss: 0.0476 - 333ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_gru.rename(columns={
    'Temp_ca':'Temp_ca_gru', 
    'NOx_ca':'NOx_ca_gru', 
    'CO_ca':'CO_ca_gru', 
    'Chuva_ca':'Chuva_ca_gru', 
    'Pres_ca':'Pres_ca_gru',
    'Vel_Vento_ca':'Vel_Vento_ca_gru',
    'SO2_ca':'SO2_ca_gru', 
    'PM10_ca':'PM10_ca_gru', 
    'O3_ca':'O3_ca_gru', 
    'UR_ca':'UR_ca_gru', 
    'NO_ca':'NO_ca_gru', 
    'NO2_ca':'NO2_ca_gru'
}, inplace=True)

# %% [markdown]
# **RNN**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_rnn=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 50/50 - 3s - loss: 0.1064 - val_loss: 0.0565 - 3s/epoch - 55ms/step
# Epoch 2/150
# 50/50 - 0s - loss: 0.0535 - val_loss: 0.0523 - 372ms/epoch - 7ms/step
# Epoch 3/150
# 50/50 - 0s - loss: 0.0452 - val_loss: 0.0524 - 404ms/epoch - 8ms/step
# Epoch 4/150
# 50/50 - 0s - loss: 0.0413 - val_loss: 0.0538 - 370ms/epoch - 7ms/step
# Epoch 5/150
# 50/50 - 0s - loss: 0.0394 - val_loss: 0.0526 - 380ms/epoch - 8ms/step
# Epoch 6/150
# 50/50 - 0s - loss: 0.0376 - val_loss: 0.0493 - 370ms/epoch - 7ms/step
# Epoch 7/150
# 50/50 - 0s - loss: 0.0355 - val_loss: 0.0484 - 368ms/epoch - 7ms/step
# Epoch 8/150
# 50/50 - 0s - loss: 0.0342 - val_loss: 0.0483 - 389ms/epoch - 8ms/step
# Epoch 9/150
# 50/50 - 0s - loss: 0.0334 - val_loss: 0.0483 - 381ms/epoch - 8ms/step
# Epoch 10/150
# 50/50 - 0s - loss: 0.0329 - val_loss: 0.0484 - 368ms/epoch - 7ms/step
# Epoch 11/150
# 50/50 - 0s - loss: 0.0325 - val_loss: 0.0486 - 391ms/epoch - 8ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_rnn.rename(columns={
    'Temp_ca':'Temp_ca_rnn', 
    'NOx_ca':'NOx_ca_rnn', 
    'CO_ca':'CO_ca_rnn', 
    'Chuva_ca':'Chuva_ca_rnn', 
    'Pres_ca':'Pres_ca_rnn',
    'Vel_Vento_ca':'Vel_Vento_ca_rnn',
    'SO2_ca':'SO2_ca_rnn', 
    'PM10_ca':'PM10_ca_rnn', 
    'O3_ca':'O3_ca_rnn', 
    'UR_ca':'UR_ca_rnn', 
    'NO_ca':'NO_ca_rnn', 
    'NO2_ca':'NO2_ca_rnn'
}, inplace=True)

# %% [markdown]
# **Montagem do ensemble**

# %%
df_concat = pd.concat([df_inv_yhat_lstm, df_inv_yhat_gru,df_inv_yhat_rnn], axis=1)

# %%
col_names =  ['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca','Vel_Vento_ca','SO2_ca', 
              'PM10_ca', 'O3_ca', 'UR_ca', 'NO_ca', 'NO2_ca']
df_inv_yhat  = pd.DataFrame(columns = col_names,index=[i for i in range(len(df_concat))])
#df_inv_yhat

# %%
#Temp_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_RNN_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    elif RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_GRU_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_lstm'][i]))/6    
    elif RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_lstm'][i]))/6

# %%
#NOx_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_RNN_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    elif RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_GRU_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_lstm'][i]))/6    
    elif RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_lstm'][i]))/6

# %%
#CO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_RNN_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_gru'][i]))/6    
    elif RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_GRU_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_lstm'][i]))/6    
    elif RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_lstm'][i]))/6

# %%
#Chuva_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    elif RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_GRU_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_lstm'][i]))/6    
    elif RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_lstm'][i]))/6

# %%
#Pres_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_RNN_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    elif RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_GRU_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_lstm'][i]))/6    
    elif RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_lstm'][i]))/6

# %%
#Vel_Vento_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    elif RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_GRU_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6    
    elif RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6

# %%
#SO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_RNN_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_GRU_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_lstm'][i]))/6

# %%
#PM10_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_RNN_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    elif RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_GRU_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_lstm'][i]))/6    
    elif RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    else:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_lstm'][i]))/6

# %%
#O3_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_RNN_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_gru'][i]))/6    
    elif RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_GRU_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_lstm'][i]))/6    
    elif RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_gru'][i]))/6    
    else:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_lstm'][i]))/6

# %%
#UR_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_RNN_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_gru'][i]))/6    
    elif RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_GRU_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_lstm'][i]))/6    
    elif RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_gru'][i]))/6    
    else:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_lstm'][i]))/6

# %%
#NO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_RNN_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_GRU_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_lstm'][i]))/6

# %%
#NO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_RNN_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_GRU_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_lstm'][i]))/6

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.174
# Test NOx_ca RMSE: 29.582
# Test CO_ca RMSE: 0.221
# Test Chuva_ca RMSE: 0.784
# Test Pres_ca RMSE: 2.490
# Test Vel_Vento_ca RMSE: 0.475
# Test SO2_ca RMSE: 5.338
# Test PM10_ca RMSE: 13.653
# Test O3_ca RMSE: 15.513
# Test UR_ca RMSE: 6.757
# Test NO_ca RMSE: 20.474
# Test NO2_ca RMSE: 17.469

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.501
# Test NOx_ca MAE: 23.575
# Test CO_ca MAE: 0.176
# Test Chuva_ca MAE: 0.575
# Test Pres_ca MAE: 1.950
# Test Vel_Vento_ca MAE: 0.382
# Test SO2_ca MAE: 4.425
# Test PM10_ca MAE: 10.876
# Test O3_ca MAE: 12.231
# Test UR_ca MAE: 5.478
# Test NO_ca MAE: 15.906
# Test NO2_ca MAE: 13.181

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: 0.007
# Test NOx_ca R2: -0.386
# Test CO_ca R2: -2.872
# Test Chuva_ca R2: -4.054
# Test Pres_ca R2: 0.608
# Test Vel_Vento_ca R2: -3.751
# Test SO2_ca R2: -2.198
# Test PM10_ca R2: -0.639
# Test O3_ca R2: -1.193
# Test UR_ca R2: -2.224
# Test NO_ca R2: -0.149
# Test NO2_ca R2: 0.092

# %% [markdown]
# ### validação cruzada (4/5)

# %% [markdown]
# **pré-processamento**

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:2640]

# split into train and test sets
values = reframed.values
n_train_days = 2112

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# %% [markdown]
# **treinamento LSTM**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat_lstm=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
df_test_y=pd.DataFrame(inv_test_y,columns=names)
# Out:
# Epoch 1/150
# 66/66 - 4s - loss: 0.1600 - val_loss: 0.0585 - 4s/epoch - 67ms/step
# Epoch 2/150
# 66/66 - 0s - loss: 0.0499 - val_loss: 0.0572 - 358ms/epoch - 5ms/step
# Epoch 3/150
# 66/66 - 0s - loss: 0.0493 - val_loss: 0.0560 - 359ms/epoch - 5ms/step
# Epoch 4/150
# 66/66 - 0s - loss: 0.0484 - val_loss: 0.0549 - 345ms/epoch - 5ms/step
# Epoch 5/150
# 66/66 - 0s - loss: 0.0475 - val_loss: 0.0535 - 349ms/epoch - 5ms/step
# Epoch 6/150
# 66/66 - 0s - loss: 0.0461 - val_loss: 0.0514 - 355ms/epoch - 5ms/step
# Epoch 7/150
# 66/66 - 0s - loss: 0.0442 - val_loss: 0.0482 - 369ms/epoch - 6ms/step
# Epoch 8/150
# 66/66 - 0s - loss: 0.0415 - val_loss: 0.0448 - 366ms/epoch - 6ms/step
# Epoch 9/150
# 66/66 - 0s - loss: 0.0390 - val_loss: 0.0429 - 369ms/epoch - 6ms/step
# Epoch 10/150
# 66/66 - 0s - loss: 0.0377 - val_loss: 0.0419 - 366ms/epoch - 6ms/step
# Epoch 11/150
# 66/66 - 0s - loss: 0.0369 - val_loss: 0.0412 - 367ms/epoch - 6ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_lstm.rename(columns={
    'Temp_ca':'Temp_ca_lstm', 
    'NOx_ca':'NOx_ca_lstm', 
    'CO_ca':'CO_ca_lstm', 
    'Chuva_ca':'Chuva_ca_lstm', 
    'Pres_ca':'Pres_ca_lstm',
    'Vel_Vento_ca':'Vel_Vento_ca_lstm',
    'SO2_ca':'SO2_ca_lstm', 
    'PM10_ca':'PM10_ca_lstm', 
    'O3_ca':'O3_ca_lstm', 
    'UR_ca':'UR_ca_lstm', 
    'NO_ca':'NO_ca_lstm', 
    'NO2_ca':'NO2_ca_lstm'
}, inplace=True)

# %% [markdown]
# **GRU**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_gru=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 66/66 - 4s - loss: 0.1164 - val_loss: 0.0566 - 4s/epoch - 68ms/step
# Epoch 2/150
# 66/66 - 0s - loss: 0.0485 - val_loss: 0.0532 - 340ms/epoch - 5ms/step
# Epoch 3/150
# 66/66 - 0s - loss: 0.0457 - val_loss: 0.0503 - 343ms/epoch - 5ms/step
# Epoch 4/150
# 66/66 - 0s - loss: 0.0428 - val_loss: 0.0480 - 316ms/epoch - 5ms/step
# Epoch 5/150
# 66/66 - 0s - loss: 0.0399 - val_loss: 0.0472 - 323ms/epoch - 5ms/step
# Epoch 6/150
# 66/66 - 0s - loss: 0.0379 - val_loss: 0.0475 - 334ms/epoch - 5ms/step
# Epoch 7/150
# 66/66 - 0s - loss: 0.0367 - val_loss: 0.0482 - 335ms/epoch - 5ms/step
# Epoch 8/150
# 66/66 - 0s - loss: 0.0359 - val_loss: 0.0488 - 349ms/epoch - 5ms/step
# Epoch 9/150
# 66/66 - 0s - loss: 0.0353 - val_loss: 0.0492 - 343ms/epoch - 5ms/step
# Epoch 10/150
# 66/66 - 0s - loss: 0.0349 - val_loss: 0.0494 - 326ms/epoch - 5ms/step
# Epoch 11/150
# 66/66 - 0s - loss: 0.0345 - val_loss: 0.0495 - 340ms/epoch - 5ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_gru.rename(columns={
    'Temp_ca':'Temp_ca_gru', 
    'NOx_ca':'NOx_ca_gru', 
    'CO_ca':'CO_ca_gru', 
    'Chuva_ca':'Chuva_ca_gru', 
    'Pres_ca':'Pres_ca_gru',
    'Vel_Vento_ca':'Vel_Vento_ca_gru',
    'SO2_ca':'SO2_ca_gru', 
    'PM10_ca':'PM10_ca_gru', 
    'O3_ca':'O3_ca_gru', 
    'UR_ca':'UR_ca_gru', 
    'NO_ca':'NO_ca_gru', 
    'NO2_ca':'NO2_ca_gru'
}, inplace=True)

# %% [markdown]
# **RNN**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_rnn=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 66/66 - 2s - loss: 0.1091 - val_loss: 0.0561 - 2s/epoch - 33ms/step
# Epoch 2/150
# 66/66 - 0s - loss: 0.0489 - val_loss: 0.0527 - 354ms/epoch - 5ms/step
# Epoch 3/150
# 66/66 - 0s - loss: 0.0441 - val_loss: 0.0520 - 372ms/epoch - 6ms/step
# Epoch 4/150
# 66/66 - 0s - loss: 0.0414 - val_loss: 0.0518 - 336ms/epoch - 5ms/step
# Epoch 5/150
# 66/66 - 0s - loss: 0.0399 - val_loss: 0.0516 - 340ms/epoch - 5ms/step
# Epoch 6/150
# 66/66 - 0s - loss: 0.0388 - val_loss: 0.0514 - 392ms/epoch - 6ms/step
# Epoch 7/150
# 66/66 - 0s - loss: 0.0379 - val_loss: 0.0512 - 378ms/epoch - 6ms/step
# Epoch 8/150
# 66/66 - 0s - loss: 0.0371 - val_loss: 0.0511 - 375ms/epoch - 6ms/step
# Epoch 9/150
# 66/66 - 0s - loss: 0.0364 - val_loss: 0.0509 - 338ms/epoch - 5ms/step
# Epoch 10/150
# 66/66 - 0s - loss: 0.0358 - val_loss: 0.0506 - 341ms/epoch - 5ms/step
# Epoch 11/150
# 66/66 - 0s - loss: 0.0352 - val_loss: 0.0504 - 351ms/epoch - 5ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_rnn.rename(columns={
    'Temp_ca':'Temp_ca_rnn', 
    'NOx_ca':'NOx_ca_rnn', 
    'CO_ca':'CO_ca_rnn', 
    'Chuva_ca':'Chuva_ca_rnn', 
    'Pres_ca':'Pres_ca_rnn',
    'Vel_Vento_ca':'Vel_Vento_ca_rnn',
    'SO2_ca':'SO2_ca_rnn', 
    'PM10_ca':'PM10_ca_rnn', 
    'O3_ca':'O3_ca_rnn', 
    'UR_ca':'UR_ca_rnn', 
    'NO_ca':'NO_ca_rnn', 
    'NO2_ca':'NO2_ca_rnn'
}, inplace=True)

# %% [markdown]
# **Montagem do ensemble**

# %%
df_concat = pd.concat([df_inv_yhat_lstm, df_inv_yhat_gru,df_inv_yhat_rnn], axis=1)

# %%
col_names =  ['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca','Vel_Vento_ca','SO2_ca', 
              'PM10_ca', 'O3_ca', 'UR_ca', 'NO_ca', 'NO2_ca']
df_inv_yhat  = pd.DataFrame(columns = col_names,index=[i for i in range(len(df_concat))])
#df_inv_yhat

# %%
#Temp_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_RNN_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    elif RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_GRU_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_lstm'][i]))/6    
    elif RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_lstm'][i]))/6

# %%
#NOx_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_RNN_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    elif RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_GRU_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_lstm'][i]))/6    
    elif RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_lstm'][i]))/6

# %%
#CO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_RNN_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_gru'][i]))/6    
    elif RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_GRU_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_lstm'][i]))/6    
    elif RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_lstm'][i]))/6

# %%
#Chuva_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    elif RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_GRU_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_lstm'][i]))/6    
    elif RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_lstm'][i]))/6

# %%
#Pres_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_RNN_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    elif RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_GRU_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_lstm'][i]))/6    
    elif RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_lstm'][i]))/6

# %%
#Vel_Vento_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    elif RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_GRU_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6    
    elif RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6

# %%
#SO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_RNN_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_GRU_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_lstm'][i]))/6

# %%
#PM10_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_RNN_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    elif RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_GRU_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_lstm'][i]))/6    
    elif RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    else:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_lstm'][i]))/6

# %%
#O3_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_RNN_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_gru'][i]))/6    
    elif RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_GRU_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_lstm'][i]))/6    
    elif RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_gru'][i]))/6    
    else:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_lstm'][i]))/6

# %%
#UR_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_RNN_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_gru'][i]))/6    
    elif RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_GRU_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_lstm'][i]))/6    
    elif RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_gru'][i]))/6    
    else:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_lstm'][i]))/6

# %%
#NO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_RNN_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_GRU_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_lstm'][i]))/6

# %%
#NO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_RNN_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_GRU_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_lstm'][i]))/6

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.076
# Test NOx_ca RMSE: 27.661
# Test CO_ca RMSE: 0.201
# Test Chuva_ca RMSE: 0.846
# Test Pres_ca RMSE: 2.264
# Test Vel_Vento_ca RMSE: 0.448
# Test SO2_ca RMSE: 5.300
# Test PM10_ca RMSE: 13.806
# Test O3_ca RMSE: 15.923
# Test UR_ca RMSE: 9.926
# Test NO_ca RMSE: 19.587
# Test NO2_ca RMSE: 16.574

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.414
# Test NOx_ca MAE: 20.347
# Test CO_ca MAE: 0.161
# Test Chuva_ca MAE: 0.552
# Test Pres_ca MAE: 1.773
# Test Vel_Vento_ca MAE: 0.363
# Test SO2_ca MAE: 4.417
# Test PM10_ca MAE: 11.002
# Test O3_ca MAE: 13.292
# Test UR_ca MAE: 7.696
# Test NO_ca MAE: 15.153
# Test NO2_ca MAE: 12.631

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.369
# Test NOx_ca R2: 0.100
# Test CO_ca R2: -1.510
# Test Chuva_ca R2: -5.723
# Test Pres_ca R2: 0.552
# Test Vel_Vento_ca R2: -5.037
# Test SO2_ca R2: -2.817
# Test PM10_ca R2: -1.284
# Test O3_ca R2: -1.553
# Test UR_ca R2: -3.384
# Test NO_ca R2: -0.327
# Test NO2_ca R2: 0.323

# %% [markdown]
# ### validação cruzada (5/5)

# %% [markdown]
# **pré-processamento**

# %%
reframed = series_to_supervised(df_ca_new_scaled, n_days, 1)

#split 1: 528 + 528

reframed = reframed[:3168]

# split into train and test sets
values = reframed.values
n_train_days = 2640

train = values[:n_train_days, :]

test = values[n_train_days:, :]

# split into input and outputs
n_obs = n_days * n_features

train_X= train[:, :n_obs]

train_y = train[:,n_obs:]

test_X = test[:, :n_obs]

test_y = test[:, n_obs:]

train_X= train_X.reshape((train_X.shape[0], 1, n_obs))
train_y = train_y.reshape((train_y.shape[0], 1, n_features))
test_X= test_X.reshape((test_X.shape[0], 1, n_obs))
test_y = test_y.reshape((test_y.shape[0], 1, n_features))

# %% [markdown]
# **treinamento LSTM**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(LSTM(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(LSTM(64,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
# model.add(LSTM(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat_teste = yhat.reshape((yhat.shape[0], n_features))

yhat = yhat.reshape((yhat.shape[0], n_features))
test_y = test_y.reshape((test_y.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)

inv_test_y = scaler.inverse_transform(test_y)

#dataframe
df_inv_yhat_lstm=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
df_test_y=pd.DataFrame(inv_test_y,columns=names)
# Out:
# Epoch 1/150
# 83/83 - 5s - loss: 0.1384 - val_loss: 0.0504 - 5s/epoch - 61ms/step
# Epoch 2/150
# 83/83 - 1s - loss: 0.0510 - val_loss: 0.0500 - 501ms/epoch - 6ms/step
# Epoch 3/150
# 83/83 - 1s - loss: 0.0505 - val_loss: 0.0496 - 512ms/epoch - 6ms/step
# Epoch 4/150
# 83/83 - 1s - loss: 0.0498 - val_loss: 0.0491 - 533ms/epoch - 6ms/step
# Epoch 5/150
# 83/83 - 1s - loss: 0.0488 - val_loss: 0.0481 - 502ms/epoch - 6ms/step
# Epoch 6/150
# 83/83 - 1s - loss: 0.0473 - val_loss: 0.0463 - 512ms/epoch - 6ms/step
# Epoch 7/150
# 83/83 - 1s - loss: 0.0451 - val_loss: 0.0434 - 502ms/epoch - 6ms/step
# Epoch 8/150
# 83/83 - 1s - loss: 0.0424 - val_loss: 0.0408 - 518ms/epoch - 6ms/step
# Epoch 9/150
# 83/83 - 1s - loss: 0.0401 - val_loss: 0.0394 - 503ms/epoch - 6ms/step
# Epoch 10/150
# 83/83 - 1s - loss: 0.0387 - val_loss: 0.0387 - 509ms/epoch - 6ms/step
# Epoch 11/150
# 83/83 - 0s - loss: 0.0378 - val_loss: 0.0381 - 496ms/epoch - 6ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_lstm.rename(columns={
    'Temp_ca':'Temp_ca_lstm', 
    'NOx_ca':'NOx_ca_lstm', 
    'CO_ca':'CO_ca_lstm', 
    'Chuva_ca':'Chuva_ca_lstm', 
    'Pres_ca':'Pres_ca_lstm',
    'Vel_Vento_ca':'Vel_Vento_ca_lstm',
    'SO2_ca':'SO2_ca_lstm', 
    'PM10_ca':'PM10_ca_lstm', 
    'O3_ca':'O3_ca_lstm', 
    'UR_ca':'UR_ca_lstm', 
    'NO_ca':'NO_ca_lstm', 
    'NO2_ca':'NO2_ca_lstm'
}, inplace=True)

# %% [markdown]
# **GRU**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(GRU(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(GRU(64,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
# model.add(GRU(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_gru=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 83/83 - 5s - loss: 0.1235 - val_loss: 0.0522 - 5s/epoch - 60ms/step
# Epoch 2/150
# 83/83 - 0s - loss: 0.0492 - val_loss: 0.0508 - 461ms/epoch - 6ms/step
# Epoch 3/150
# 83/83 - 1s - loss: 0.0472 - val_loss: 0.0495 - 514ms/epoch - 6ms/step
# Epoch 4/150
# 83/83 - 0s - loss: 0.0448 - val_loss: 0.0480 - 485ms/epoch - 6ms/step
# Epoch 5/150
# 83/83 - 0s - loss: 0.0421 - val_loss: 0.0464 - 480ms/epoch - 6ms/step
# Epoch 6/150
# 83/83 - 0s - loss: 0.0396 - val_loss: 0.0455 - 483ms/epoch - 6ms/step
# Epoch 7/150
# 83/83 - 0s - loss: 0.0378 - val_loss: 0.0451 - 489ms/epoch - 6ms/step
# Epoch 8/150
# 83/83 - 0s - loss: 0.0367 - val_loss: 0.0449 - 460ms/epoch - 6ms/step
# Epoch 9/150
# 83/83 - 0s - loss: 0.0357 - val_loss: 0.0447 - 467ms/epoch - 6ms/step
# Epoch 10/150
# 83/83 - 0s - loss: 0.0349 - val_loss: 0.0445 - 481ms/epoch - 6ms/step
# Epoch 11/150
# 83/83 - 0s - loss: 0.0342 - val_loss: 0.0442 - 474ms/epoch - 6ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_gru.rename(columns={
    'Temp_ca':'Temp_ca_gru', 
    'NOx_ca':'NOx_ca_gru', 
    'CO_ca':'CO_ca_gru', 
    'Chuva_ca':'Chuva_ca_gru', 
    'Pres_ca':'Pres_ca_gru',
    'Vel_Vento_ca':'Vel_Vento_ca_gru',
    'SO2_ca':'SO2_ca_gru', 
    'PM10_ca':'PM10_ca_gru', 
    'O3_ca':'O3_ca_gru', 
    'UR_ca':'UR_ca_gru', 
    'NO_ca':'NO_ca_gru', 
    'NO2_ca':'NO2_ca_gru'
}, inplace=True)

# %% [markdown]
# **RNN**

# %%
# design network (falta ajustar o numero de camadas, neurônios etc)
opt = Adam(learning_rate=0.0005)
model = Sequential()
model.add(SimpleRNN(input_shape=(1,84),return_sequences=True, units=84)) #return=True é para retornar todas as variáveis
model.add(TimeDistributed(Dense(12))) # é numero de variáveis
model.add(SimpleRNN(64,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
# model.add(SimpleRNN(128,return_sequences=True))
model.add(TimeDistributed(Dense(12)))
model.compile(loss='mse', optimizer=opt)

a=time.time()
history = model.fit(train_X, train_y, epochs=150, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
print("\nModel Runtime: %0.2f seconds"%((time.time() - a)))

yhat = model.predict(test_X)
yhat = yhat.reshape((yhat.shape[0], n_features))
inv_yhat = scaler.inverse_transform(yhat)
df_inv_yhat_rnn=pd.DataFrame(inv_yhat,columns=names) #mudar o nome do modelo aqui
# Out:
# Epoch 1/150
# 83/83 - 2s - loss: 0.0950 - val_loss: 0.0671 - 2s/epoch - 30ms/step
# Epoch 2/150
# 83/83 - 1s - loss: 0.0508 - val_loss: 0.0582 - 595ms/epoch - 7ms/step
# Epoch 3/150
# 83/83 - 1s - loss: 0.0452 - val_loss: 0.0538 - 569ms/epoch - 7ms/step
# Epoch 4/150
# 83/83 - 1s - loss: 0.0416 - val_loss: 0.0515 - 578ms/epoch - 7ms/step
# Epoch 5/150
# 83/83 - 1s - loss: 0.0392 - val_loss: 0.0503 - 564ms/epoch - 7ms/step
# Epoch 6/150
# 83/83 - 1s - loss: 0.0376 - val_loss: 0.0494 - 547ms/epoch - 7ms/step
# Epoch 7/150
# 83/83 - 1s - loss: 0.0365 - val_loss: 0.0488 - 565ms/epoch - 7ms/step
# Epoch 8/150
# 83/83 - 1s - loss: 0.0357 - val_loss: 0.0485 - 573ms/epoch - 7ms/step
# Epoch 9/150
# 83/83 - 1s - loss: 0.0351 - val_loss: 0.0483 - 552ms/epoch - 7ms/step
# Epoch 10/150
# 83/83 - 1s - loss: 0.0346 - val_loss: 0.0481 - 569ms/epoch - 7ms/step
# Epoch 11/150
# 83/83 - 1s - loss: 0.0342 - val_loss: 0.0479 - 561ms/epoch - 7ms/step
# Epoch 12/150
# ...

# %%
df_inv_yhat_rnn.rename(columns={
    'Temp_ca':'Temp_ca_rnn', 
    'NOx_ca':'NOx_ca_rnn', 
    'CO_ca':'CO_ca_rnn', 
    'Chuva_ca':'Chuva_ca_rnn', 
    'Pres_ca':'Pres_ca_rnn',
    'Vel_Vento_ca':'Vel_Vento_ca_rnn',
    'SO2_ca':'SO2_ca_rnn', 
    'PM10_ca':'PM10_ca_rnn', 
    'O3_ca':'O3_ca_rnn', 
    'UR_ca':'UR_ca_rnn', 
    'NO_ca':'NO_ca_rnn', 
    'NO2_ca':'NO2_ca_rnn'
}, inplace=True)

# %% [markdown]
# **Montagem do ensemble**

# %%
df_concat = pd.concat([df_inv_yhat_lstm, df_inv_yhat_gru,df_inv_yhat_rnn], axis=1)

# %%
col_names =  ['Temp_ca', 'NOx_ca', 'CO_ca', 'Chuva_ca', 'Pres_ca','Vel_Vento_ca','SO2_ca', 
              'PM10_ca', 'O3_ca', 'UR_ca', 'NO_ca', 'NO2_ca']
df_inv_yhat  = pd.DataFrame(columns = col_names,index=[i for i in range(len(df_concat))])
#df_inv_yhat

# %%
#Temp_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_RNN_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    elif RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca and RMSE_GRU_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_lstm'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_RNN_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_rnn'][i]))/6    
    elif RMSE_GRU_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_gru'][i])+(2*df_concat['Temp_ca_rnn'][i])+(df_concat['Temp_ca_lstm'][i]))/6    
    elif RMSE_RNN_Temp_ca > RMSE_LSTM_Temp_ca and RMSE_LSTM_Temp_ca > RMSE_GRU_Temp_ca:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_lstm'][i])+(df_concat['Temp_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Temp_ca'][i]=((3*df_concat['Temp_ca_rnn'][i])+(2*df_concat['Temp_ca_gru'][i])+(df_concat['Temp_ca_lstm'][i]))/6

# %%
#NOx_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_RNN_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    elif RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca and RMSE_GRU_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_lstm'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_RNN_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_rnn'][i]))/6    
    elif RMSE_GRU_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_gru'][i])+(2*df_concat['NOx_ca_rnn'][i])+(df_concat['NOx_ca_lstm'][i]))/6    
    elif RMSE_RNN_NOx_ca > RMSE_LSTM_NOx_ca and RMSE_LSTM_NOx_ca > RMSE_GRU_NOx_ca:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_lstm'][i])+(df_concat['NOx_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NOx_ca'][i]=((3*df_concat['NOx_ca_rnn'][i])+(2*df_concat['NOx_ca_gru'][i])+(df_concat['NOx_ca_lstm'][i]))/6

# %%
#CO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_RNN_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_gru'][i]))/6    
    elif RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca and RMSE_GRU_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_lstm'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_RNN_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_rnn'][i]))/6    
    elif RMSE_GRU_CO_ca > RMSE_LSTM_CO_ca and RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_gru'][i])+(2*df_concat['CO_ca_rnn'][i])+(df_concat['CO_ca_lstm'][i]))/6    
    elif RMSE_RNN_CO_ca > RMSE_LSTM_CO_ca and RMSE_LSTM_CO_ca > RMSE_GRU_CO_ca:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_lstm'][i])+(df_concat['CO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['CO_ca'][i]=((3*df_concat['CO_ca_rnn'][i])+(2*df_concat['CO_ca_gru'][i])+(df_concat['CO_ca_lstm'][i]))/6

# %%
#Chuva_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    elif RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca and RMSE_GRU_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_lstm'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_RNN_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_rnn'][i]))/6    
    elif RMSE_GRU_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_gru'][i])+(2*df_concat['Chuva_ca_rnn'][i])+(df_concat['Chuva_ca_lstm'][i]))/6    
    elif RMSE_RNN_Chuva_ca > RMSE_LSTM_Chuva_ca and RMSE_LSTM_Chuva_ca > RMSE_GRU_Chuva_ca:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_lstm'][i])+(df_concat['Chuva_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Chuva_ca'][i]=((3*df_concat['Chuva_ca_rnn'][i])+(2*df_concat['Chuva_ca_gru'][i])+(df_concat['Chuva_ca_lstm'][i]))/6

# %%
#Pres_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_RNN_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    elif RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca and RMSE_GRU_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_lstm'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_RNN_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_rnn'][i]))/6    
    elif RMSE_GRU_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_gru'][i])+(2*df_concat['Pres_ca_rnn'][i])+(df_concat['Pres_ca_lstm'][i]))/6    
    elif RMSE_RNN_Pres_ca > RMSE_LSTM_Pres_ca and RMSE_LSTM_Pres_ca > RMSE_GRU_Pres_ca:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_lstm'][i])+(df_concat['Pres_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Pres_ca'][i]=((3*df_concat['Pres_ca_rnn'][i])+(2*df_concat['Pres_ca_gru'][i])+(df_concat['Pres_ca_lstm'][i]))/6

# %%
#Vel_Vento_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    elif RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca and RMSE_GRU_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_lstm'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_RNN_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_rnn'][i]))/6    
    elif RMSE_GRU_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_gru'][i])+(2*df_concat['Vel_Vento_ca_rnn'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6    
    elif RMSE_RNN_Vel_Vento_ca > RMSE_LSTM_Vel_Vento_ca and RMSE_LSTM_Vel_Vento_ca > RMSE_GRU_Vel_Vento_ca:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_lstm'][i])+(df_concat['Vel_Vento_ca_gru'][i]))/6    
    else:
        df_inv_yhat['Vel_Vento_ca'][i]=((3*df_concat['Vel_Vento_ca_rnn'][i])+(2*df_concat['Vel_Vento_ca_gru'][i])+(df_concat['Vel_Vento_ca_lstm'][i]))/6

# %%
#SO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_RNN_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca and RMSE_GRU_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_lstm'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_RNN_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_gru'][i])+(2*df_concat['SO2_ca_rnn'][i])+(df_concat['SO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_SO2_ca > RMSE_LSTM_SO2_ca and RMSE_LSTM_SO2_ca > RMSE_GRU_SO2_ca:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_lstm'][i])+(df_concat['SO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['SO2_ca'][i]=((3*df_concat['SO2_ca_rnn'][i])+(2*df_concat['SO2_ca_gru'][i])+(df_concat['SO2_ca_lstm'][i]))/6

# %%
#PM10_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_RNN_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    elif RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca and RMSE_GRU_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_lstm'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_RNN_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_rnn'][i]))/6    
    elif RMSE_GRU_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_gru'][i])+(2*df_concat['PM10_ca_rnn'][i])+(df_concat['PM10_ca_lstm'][i]))/6    
    elif RMSE_RNN_PM10_ca > RMSE_LSTM_PM10_ca and RMSE_LSTM_PM10_ca > RMSE_GRU_PM10_ca:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_lstm'][i])+(df_concat['PM10_ca_gru'][i]))/6    
    else:
        df_inv_yhat['PM10_ca'][i]=((3*df_concat['PM10_ca_rnn'][i])+(2*df_concat['PM10_ca_gru'][i])+(df_concat['PM10_ca_lstm'][i]))/6

# %%
#O3_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_RNN_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_gru'][i]))/6    
    elif RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca and RMSE_GRU_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_lstm'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_RNN_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_rnn'][i]))/6    
    elif RMSE_GRU_O3_ca > RMSE_LSTM_O3_ca and RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_gru'][i])+(2*df_concat['O3_ca_rnn'][i])+(df_concat['O3_ca_lstm'][i]))/6    
    elif RMSE_RNN_O3_ca > RMSE_LSTM_O3_ca and RMSE_LSTM_O3_ca > RMSE_GRU_O3_ca:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_lstm'][i])+(df_concat['O3_ca_gru'][i]))/6    
    else:
        df_inv_yhat['O3_ca'][i]=((3*df_concat['O3_ca_rnn'][i])+(2*df_concat['O3_ca_gru'][i])+(df_concat['O3_ca_lstm'][i]))/6

# %%
#UR_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_RNN_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_gru'][i]))/6    
    elif RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca and RMSE_GRU_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_lstm'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_RNN_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_rnn'][i]))/6    
    elif RMSE_GRU_UR_ca > RMSE_LSTM_UR_ca and RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_gru'][i])+(2*df_concat['UR_ca_rnn'][i])+(df_concat['UR_ca_lstm'][i]))/6    
    elif RMSE_RNN_UR_ca > RMSE_LSTM_UR_ca and RMSE_LSTM_UR_ca > RMSE_GRU_UR_ca:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_lstm'][i])+(df_concat['UR_ca_gru'][i]))/6    
    else:
        df_inv_yhat['UR_ca'][i]=((3*df_concat['UR_ca_rnn'][i])+(2*df_concat['UR_ca_gru'][i])+(df_concat['UR_ca_lstm'][i]))/6

# %%
#NO_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_RNN_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca and RMSE_GRU_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_lstm'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_RNN_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO_ca > RMSE_LSTM_NO_ca and RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_gru'][i])+(2*df_concat['NO_ca_rnn'][i])+(df_concat['NO_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO_ca > RMSE_LSTM_NO_ca and RMSE_LSTM_NO_ca > RMSE_GRU_NO_ca:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_lstm'][i])+(df_concat['NO_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO_ca'][i]=((3*df_concat['NO_ca_rnn'][i])+(2*df_concat['NO_ca_gru'][i])+(df_concat['NO_ca_lstm'][i]))/6

# %%
#NO2_ca
for i in range(len(df_inv_yhat)):
    
    if RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_RNN_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    elif RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca and RMSE_GRU_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_lstm'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_RNN_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_rnn'][i]))/6    
    elif RMSE_GRU_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_gru'][i])+(2*df_concat['NO2_ca_rnn'][i])+(df_concat['NO2_ca_lstm'][i]))/6    
    elif RMSE_RNN_NO2_ca > RMSE_LSTM_NO2_ca and RMSE_LSTM_NO2_ca > RMSE_GRU_NO2_ca:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_lstm'][i])+(df_concat['NO2_ca_gru'][i]))/6    
    else:
        df_inv_yhat['NO2_ca'][i]=((3*df_concat['NO2_ca_rnn'][i])+(2*df_concat['NO2_ca_gru'][i])+(df_concat['NO2_ca_lstm'][i]))/6

# %%
rmse = sqrt(mean_squared_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca']))
lista_Temp_ca_RMSE.append(rmse)
print('Test Temp_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca']))
lista_NOx_ca_RMSE.append(rmse)
print('Test NOx_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca']))
lista_CO_ca_RMSE.append(rmse)
print('Test CO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca']))
lista_Chuva_ca_RMSE.append(rmse)
print('Test Chuva_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca']))
lista_Pres_ca_RMSE.append(rmse)
print('Test Pres_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca']))
lista_Vel_Vento_ca_RMSE.append(rmse)
print('Test Vel_Vento_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca']))
lista_SO2_ca_RMSE.append(rmse)
print('Test SO2_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca']))
lista_PM10_ca_RMSE.append(rmse)
print('Test PM10_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca']))
lista_O3_ca_RMSE.append(rmse)
print('Test O3_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca']))
lista_UR_ca_RMSE.append(rmse)
print('Test UR_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca']))
lista_NO_ca_RMSE.append(rmse)
print('Test NO_ca RMSE: %.3f' % rmse)

rmse = sqrt(mean_squared_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca']))
lista_NO2_ca_RMSE.append(rmse)
print('Test NO2_ca RMSE: %.3f' % rmse)
# Out:
# Test Temp_ca RMSE: 3.626
# Test NOx_ca RMSE: 13.429
# Test CO_ca RMSE: 0.234
# Test Chuva_ca RMSE: 0.794
# Test Pres_ca RMSE: 2.668
# Test Vel_Vento_ca RMSE: 0.590
# Test SO2_ca RMSE: 5.082
# Test PM10_ca RMSE: 14.495
# Test O3_ca RMSE: 15.858
# Test UR_ca RMSE: 6.395
# Test NO_ca RMSE: 8.488
# Test NO2_ca RMSE: 7.224

# %%
mae = mean_absolute_error(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca MAE: %.3f' % mae)

mae = mean_absolute_error(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca MAE: %.3f' % mae)
# Out:
# Test Temp_ca MAE: 2.827
# Test NOx_ca MAE: 10.618
# Test CO_ca MAE: 0.192
# Test Chuva_ca MAE: 0.564
# Test Pres_ca MAE: 2.054
# Test Vel_Vento_ca MAE: 0.488
# Test SO2_ca MAE: 4.246
# Test PM10_ca MAE: 11.957
# Test O3_ca MAE: 12.619
# Test UR_ca MAE: 4.821
# Test NO_ca MAE: 6.629
# Test NO2_ca MAE: 5.481

# %%
r2=r2_score(df_inv_yhat['Temp_ca'], df_test_y['Temp_ca'])
print('Test Temp_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NOx_ca'], df_test_y['NOx_ca'])
print('Test NOx_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['CO_ca'], df_test_y['CO_ca'])
print('Test CO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Chuva_ca'], df_test_y['Chuva_ca'])
print('Test Chuva_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Pres_ca'], df_test_y['Pres_ca'])
print('Test Pres_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['Vel_Vento_ca'], df_test_y['Vel_Vento_ca'])
print('Test Vel_Vento_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['SO2_ca'], df_test_y['SO2_ca'])
print('Test SO2_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['PM10_ca'], df_test_y['PM10_ca'])
print('Test PM10_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['O3_ca'], df_test_y['O3_ca'])
print('Test O3_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['UR_ca'], df_test_y['UR_ca'])
print('Test UR_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO_ca'], df_test_y['NO_ca'])
print('Test NO_ca R2: %.3f' % r2)

r2=r2_score(df_inv_yhat['NO2_ca'], df_test_y['NO2_ca'])
print('Test NO2_ca R2: %.3f' % r2)
# Out:
# Test Temp_ca R2: -0.537
# Test NOx_ca R2: 0.843
# Test CO_ca R2: -0.789
# Test Chuva_ca R2: -3.691
# Test Pres_ca R2: 0.511
# Test Vel_Vento_ca R2: -7.060
# Test SO2_ca R2: -2.930
# Test PM10_ca R2: -0.362
# Test O3_ca R2: -0.467
# Test UR_ca R2: -0.659
# Test NO_ca R2: 0.853
# Test NO2_ca R2: 0.874

# %%
'''
1- mudar os sufixos dos nomes das colunas em cada dataframe (x)
2- unir os 3 dataframes (x)
3- gerar um dataframe vazio (x)
4- montar a lógica (x)
5- pegar rmse, mae e r2 (x)
6- replicar para k=2, k=3, k=4 e k=5 (x)
7- passar para google drive e trocar epoch, lembre-se de usar G-CPU
8- planilhar os resultados

etapas seguintes: dropout e batch normalization, ampliação da análise
'''
# Out:
# '\n1- mudar os sufixos dos nomes das colunas em cada dataframe (x)\n2- unir os 3 dataframes (x)\n3- gerar um dataframe vazio (x)\n4- montar a lógica (x)\n5- pegar rmse, mae e r2 (x)\n6- replicar para k=2, k=3, k=4 e k=5 (x)\n7- passar para google drive e trocar epoch, lembre-se de usar G-CPU\n8- planilhar os resultados\n\netapas seguintes: dropout e batch normalization, ampliação da análise\n'

# %% [markdown]
# # links sobre hiperparâmetros de redes neurais recorrentes LSTM

# %%
'''
O que foi feito nesta etapa:
----------------------------

Nesta etapa, com intuito de conseguir o melhor modelo, pesquisei sobre os hiperparâmetros que compõem as redes LSTM.
Abaixo seguem os links que salvei da pesquisa

'''

# %% [markdown]
# **-ativação (x)**
# https://keras.io/api/layers/activations/
# https://machinelearningmastery.com/choose-an-activation-function-for-deep-learning/
# https://medium.com/@snaily16/what-why-and-which-activation-functions-b2bf748c0441
# http://kth.diva-portal.org/smash/get/diva2:1465073/FULLTEXT01.pdf
#
# **-diferença entre ativação e recurrent_activation (x)**:
# https://stackoverflow.com/questions/44947842/can-someone-explain-to-me-the-difference-between-activation-and-recurrent-activa
#
# **-significado dos layers:(x)**
# https://stackoverflow.com/questions/57414387/meaning-of-tf-keras-layers-lstm-parameters
# https://machinelearningmastery.com/use-dropout-lstm-networks-time-series-forecasting/
#
# **-kernel initializer:(x)**
# https://keras.io/api/layers/initializers/
# https://towardsdatascience.com/weight-initialization-techniques-in-neural-networks-26c649eb3b78
# https://wandb.ai/sayakpaul/weight-initialization-tb/reports/Effects-of-Weight-Initialization-on-Neural-Networks--Vmlldzo2ODY0NA
#
# **-recurrent initializer:(x)**
# https://stackoverflow.com/questions/63630659/what-does-recurrent-initializer-do
# https://notebook.community/infilect/ml-course1/deep-learning-keras/keras-notebooks/RNN/7.1%20RNN%20and%20LSTM
# https://stackoverflow.com/questions/64881855/kernel-and-recurrent-kernel-in-keras-lstms
#
# **-bias initializer:(x)**
# https://www.tutorialexample.com/understand-lstm-weight-and-bias-initialization-when-initializer-is-none-in-tensorflow-tensorflow-tutorial/
# https://medium.com/@glenmeyerowitz/bias-initialization-in-a-neural-network-2e5d26fed0f0
# https://cs231n.github.io/neural-networks-2/
#
#
# **-kernel regularizer:(x)**
# https://machinelearningmastery.com/use-weight-regularization-lstm-networks-time-series-forecasting/ https://stats.stackexchange.com/questions/164876/what-is-the-trade-off-between-batch-size-and-number-of-iterations-to-train-a-neu https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/
#
# **-bias regularizer:(x)**
# https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-learning-with-weight-regularization/
#
# **-activity regularizer:(x)**
# https://machinelearningmastery.com/how-to-reduce-generalization-error-in-deep-neural-networks-with-activity-regularization-in-keras/
#
# **-kernel constraint:(x)**
# https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-neural-networks-with-weight-constraints-in-keras/
#
# **-dropout:(x)**
# https://machinelearningmastery.com/how-to-reduce-overfitting-with-dropout-regularization-in-keras/
#
# **-recurrent dropout:(x)**
# https://stackoverflow.com/questions/44924690/keras-the-difference-between-lstm-dropout-and-lstm-recurrent-dropout
#
# **-return sequences/states:(x)**
# https://machinelearningmastery.com/return-sequences-and-return-states-for-lstms-in-keras/
# https://www.dlology.com/blog/how-to-use-return_state-or-return_sequences-in-keras/
#
# **-go backwards:(x)**
# https://stackoverflow.com/questions/49946942/keras-lstm-go-backwards-usage
#
# **-stateful:(x)**
# https://machinelearningmastery.com/stateful-stateless-lstm-time-series-forecasting-python/
# https://stackoverflow.com/questions/39681046/keras-stateful-vs-stateless-lstms
#
# **-time_major:(x)**
# https://stackoverflow.com/questions/42130491/batch-major-vs-time-major-lstm
#
# **-unroll:(x)**
# https://machinelearningmastery.com/rnn-unrolling/
# https://stats.stackexchange.com/questions/492040/what-is-unrolling-in-lstm

# %% [markdown]
# número de neurônios e camadas escondidas

# %%
#https://www.temjournal.com/content/94/TEMJournalNovember2020_1320_1329.pdf *
#https://machinelearningmastery.com/how-to-configure-the-number-of-layers-and-nodes-in-a-neural-network/ *
#https://www.researchgate.net/post/How-to-decide-the-number-of-hidden-layers-and-nodes-in-a-hidden-layer
#https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw *
#https://towardsdatascience.com/beginners-ask-how-many-hidden-layers-neurons-to-use-in-artificial-neural-networks-51466afa0d3e
#https://www.linkedin.com/pulse/choosing-number-hidden-layers-neurons-neural-networks-sachdev/ *
#https://www.hindawi.com/journals/mpe/2013/425740/

# %%
#primeira fórmula: raiz do numero de input * numero de output (testar outras)
